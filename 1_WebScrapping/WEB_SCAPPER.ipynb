# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from tqdm import tqdm 
from tqdm import trange
import time

# %%
data = pd.DataFrame(columns=['INDEX','LINK','DOCUMENT'])
data_temp = pd.DataFrame(columns=['INDEX','LINK','DOCUMENT'])

# %%
root_url = 'https://www.corteconstitucional.gov.co'

# %%
#max_page = 1
max_page = 358 #son 357
print('STAGE 1/7')
for i in tqdm(range(51)):
    
    try:
        page_url = '/relatoria/providencia.aspx?pg='+ str(i) +'&buscar=&anio=&total=35718'
        main_url = root_url + page_url

        main_html_text = requests.get(main_url).text
        main_soup = BeautifulSoup(main_html_text, 'lxml')

        docs = main_soup.find_all('div', class_ = 'grow')

        for doc in docs:

            doc_link = doc.find('a')['href']

            inner_doc_url = root_url + doc_link
            html_inner_doc = requests.get(inner_doc_url).text
            inner_doc_soup = BeautifulSoup(html_inner_doc, 'lxml')

            try:
                doc_index = doc.find('a').text
                document = inner_doc_soup.find('div', class_ = 'WordSection1')
                document_text = document.text
                new_row = {'INDEX':doc_index,'LINK':inner_doc_url,'DOCUMENT':document_text}
                data_temp = data_temp.append(new_row, ignore_index=True)

            except:
                try:
                    doc_index = doc.find('a').text
                    document = inner_doc_soup.find('div', class_ = 'amplia')
                    document_text = document.text
                    new_row = {'INDEX':doc_index,'LINK':inner_doc_url,'DOCUMENT':document_text}
                    data_temp = data_temp.append(new_row, ignore_index=True)

                except Exception as e:
                    print("Error!: " + str(e))
                    print('Problema en: '+ inner_doc_url)
                    print('Pagina: ' + main_url)
                    print(' ')

    except Exception as e:
        print("Error!: " + str(e))

data = data.append(data_temp, ignore_index=True)
data_temp = pd.DataFrame(columns=['INDEX','LINK','DOCUMENT'])
# Out:
# STAGE 1/7
#  71%|███████   | 36/51 [17:27<09:07, 36.52s/it]
# Error!: HTTPSConnectionPool(host='www.corteconstitucional.gov.co', port=443): Max retries exceeded with url: /Relatoria/autos/2015/A170-15.htm (Caused by SSLError(SSLError("bad handshake: SysCallError(10054, 'WSAECONNRESET')")))
#  73%|███████▎  | 37/51 [21:45<23:59, 102.81s/it]
# Error!: HTTPSConnectionPool(host='www.corteconstitucional.gov.co', port=443): Max retries exceeded with url: /relatoria/providencia.aspx?pg=37&buscar=&anio=&total=35718 (Caused by SSLError(SSLError("bad handshake: SysCallError(10054, 'WSAECONNRESET')")))
#  78%|███████▊  | 40/51 [26:37<15:22, 83.84s/it]
# Error!: HTTPSConnectionPool(host='www.corteconstitucional.gov.co', port=443): Max retries exceeded with url: /Relatoria/autos/2014/A192-14.htm (Caused by SSLError(SSLError("bad handshake: SysCallError(10054, 'WSAECONNRESET')")))
# 100%|██████████| 51/51 [37:45<00:00, 44.43s/it]

# %%
print('STAGE 2/7')
for i in tqdm(range(51,102)):
    
    try:
        page_url = '/relatoria/providencia.aspx?pg='+ str(i) +'&buscar=&anio=&total=35718'
        main_url = root_url + page_url

        main_html_text = requests.get(main_url).text
        main_soup = BeautifulSoup(main_html_text, 'lxml')

        docs = main_soup.find_all('div', class_ = 'grow')

        for doc in docs:

            doc_link = doc.find('a')['href']

            inner_doc_url = root_url + doc_link
            html_inner_doc = requests.get(inner_doc_url).text
            inner_doc_soup = BeautifulSoup(html_inner_doc, 'lxml')

            try:
                doc_index = doc.find('a').text
                document = inner_doc_soup.find('div', class_ = 'WordSection1')
                document_text = document.text
                new_row = {'INDEX':doc_index,'LINK':inner_doc_url,'DOCUMENT':document_text}
                data_temp = data_temp.append(new_row, ignore_index=True)

            except:
                try:
                    doc_index = doc.find('a').text
                    document = inner_doc_soup.find('div', class_ = 'amplia')
                    document_text = document.text
                    new_row = {'INDEX':doc_index,'LINK':inner_doc_url,'DOCUMENT':document_text}
                    data_temp = data_temp.append(new_row, ignore_index=True)

                except Exception as e:
                    print("Error!: " + str(e))
                    print('Problema en: '+ inner_doc_url)
                    print('Pagina: ' + main_url)
                    print(' ')

    except Exception as e:
        print("Error!: " + str(e))

data = data.append(data_temp, ignore_index=True)
data_temp = pd.DataFrame(columns=['INDEX','LINK','DOCUMENT'])
# Out:
# STAGE 2/7
# 100%|██████████| 51/51 [38:32<00:00, 45.33s/it]

# %%
print('STAGE 3/7')
#for i in tqdm(range(102,153)):
for i in tqdm(range(139,153)):
    
    try:
        page_url = '/relatoria/providencia.aspx?pg='+ str(i) +'&buscar=&anio=&total=35718'
        main_url = root_url + page_url

        main_html_text = requests.get(main_url).text
        main_soup = BeautifulSoup(main_html_text, 'lxml')

        docs = main_soup.find_all('div', class_ = 'grow')

        for doc in docs:

            doc_link = doc.find('a')['href']

            inner_doc_url = root_url + doc_link
            html_inner_doc = requests.get(inner_doc_url).text
            inner_doc_soup = BeautifulSoup(html_inner_doc, 'lxml')

            try:
                doc_index = doc.find('a').text
                document = inner_doc_soup.find('div', class_ = 'WordSection1')
                document_text = document.text
                new_row = {'INDEX':doc_index,'LINK':inner_doc_url,'DOCUMENT':document_text}
                data_temp = data_temp.append(new_row, ignore_index=True)

            except:
                try:
                    doc_index = doc.find('a').text
                    document = inner_doc_soup.find('div', class_ = 'amplia')
                    document_text = document.text
                    new_row = {'INDEX':doc_index,'LINK':inner_doc_url,'DOCUMENT':document_text}
                    data_temp = data_temp.append(new_row, ignore_index=True)

                except Exception as e:
                    print("Error!: " + str(e))
                    print('Problema en: '+ inner_doc_url)
                    print('Pagina: ' + main_url)
                    print(' ')

    except Exception as e:
        print("Error!: " + str(e))

data = data.append(data_temp, ignore_index=True)
data_temp = pd.DataFrame(columns=['INDEX','LINK','DOCUMENT'])
# Out:
# STAGE 3/7
#   0%|          | 0/14 [00:00<?, ?it/s]
#
#   7%|▋         | 1/14 [10:07<2:11:31, 607.06s/it]
#
#  14%|█▍        | 2/14 [18:30<1:55:09, 575.82s/it]
#
#  21%|██▏       | 3/14 [25:13<1:36:06, 524.24s/it]
#
#  29%|██▊       | 4/14 [33:25<1:25:45, 514.60s/it]
#
#  36%|███▌      | 5/14 [38:50<1:08:37, 457.45s/it]
# Error!: ('Connection broken: OSError("(10054, \'WSAECONNRESET\')")', OSError("(10054, 'WSAECONNRESET')"))
#  43%|████▎     | 6/14 [45:18<58:14, 436.76s/it]
#
#  50%|█████     | 7/14 [51:12<48:02, 411.83s/it]
#
#  57%|█████▋    | 8/14 [57:58<41:00, 410.02s/it]
#
#  64%|██████▍   | 9/14 [1:02:38<30:55, 371.11s/it]
#
#  71%|███████▏  | 10/14 [1:09:36<25:41, 385.28s/it]
#
#  79%|███████▊  | 11/14 [1:16:29<19:40, 393.50s/it]
#
#  86%|████████▌ | 12/14 [1:25:35<14:38, 439.28s/it]
#
#  93%|█████████▎| 13/14 [1:32:22<07:09, 429.47s/it]
#
# 100%|██████████| 14/14 [1:39:28<00:00, 426.30s/it]

# %%
print('STAGE 4/7')
for i in tqdm(range(153,204)):
    
    try:
        page_url = '/relatoria/providencia.aspx?pg='+ str(i) +'&buscar=&anio=&total=35718'
        main_url = root_url + page_url

        main_html_text = requests.get(main_url).text
        main_soup = BeautifulSoup(main_html_text, 'lxml')

        docs = main_soup.find_all('div', class_ = 'grow')

        for doc in docs:

            doc_link = doc.find('a')['href']

            inner_doc_url = root_url + doc_link
            html_inner_doc = requests.get(inner_doc_url).text
            inner_doc_soup = BeautifulSoup(html_inner_doc, 'lxml')

            try:
                doc_index = doc.find('a').text
                document = inner_doc_soup.find('div', class_ = 'WordSection1')
                document_text = document.text
                new_row = {'INDEX':doc_index,'LINK':inner_doc_url,'DOCUMENT':document_text}
                data_temp = data_temp.append(new_row, ignore_index=True)

            except:
                try:
                    doc_index = doc.find('a').text
                    document = inner_doc_soup.find('div', class_ = 'amplia')
                    document_text = document.text
                    new_row = {'INDEX':doc_index,'LINK':inner_doc_url,'DOCUMENT':document_text}
                    data_temp = data_temp.append(new_row, ignore_index=True)

                except Exception as e:
                    print("Error!: " + str(e))
                    print('Problema en: '+ inner_doc_url)
                    print('Pagina: ' + main_url)
                    print(' ')

    except Exception as e:
        print("Error!: " + str(e))

data = data.append(data_temp, ignore_index=True)
data_temp = pd.DataFrame(columns=['INDEX','LINK','DOCUMENT'])
# Out:
# STAGE 4/7
#   0%|          | 0/51 [00:00<?, ?it/s]
#
#   2%|▏         | 1/51 [05:50<4:51:47, 350.14s/it]
#
#   4%|▍         | 2/51 [09:53<4:19:51, 318.19s/it]
#
#   6%|▌         | 3/51 [15:23<4:17:23, 321.74s/it]
#
#   8%|▊         | 4/51 [18:41<3:42:56, 284.61s/it]
#
#  10%|▉         | 5/51 [22:10<3:20:45, 261.86s/it]
#
#  12%|█▏        | 6/51 [24:01<2:42:27, 216.62s/it]
#
#  14%|█▎        | 7/51 [32:03<3:37:08, 296.10s/it]
#
#  16%|█▌        | 8/51 [36:37<3:27:36, 289.70s/it]
#
#  18%|█▊        | 9/51 [40:40<3:12:54, 275.59s/it]
#
#  20%|█▉        | 10/51 [42:58<2:40:11, 234.42s/it]
#
#  22%|██▏       | 11/51 [45:20<2:17:39, 206.48s/it]
#
#  24%|██▎       | 12/51 [50:42<2:36:45, 241.18s/it]
#
#  25%|██▌       | 13/51 [52:52<2:11:34, 207.76s/it]
#
#  27%|██▋       | 14/51 [55:32<1:59:17, 193.45s/it]
#
#  29%|██▉       | 15/51 [58:06<1:49:01, 181.72s/it]
#
#  31%|███▏      | 16/51 [59:59<1:33:59, 161.12s/it]
#
#  33%|███▎      | 17/51 [1:02:23<1:28:25, 156.06s/it]
#
#  35%|███▌      | 18/51 [1:04:14<1:18:24, 142.55s/it]
#
#  37%|███▋      | 19/51 [1:08:25<1:33:17, 174.92s/it]
#
#  39%|███▉      | 20/51 [1:10:08<1:19:17, 153.47s/it]
#
#  41%|████      | 21/51 [1:11:54<1:09:31, 139.04s/it]
#
#  43%|████▎     | 22/51 [1:12:26<51:41, 106.97s/it]
#
#  45%|████▌     | 23/51 [1:13:04<40:20, 86.44s/it]
#
#  47%|████▋     | 24/51 [1:16:17<53:17, 118.42s/it]
#
#  49%|████▉     | 25/51 [1:17:54<48:26, 111.79s/it]
#
#  51%|█████     | 26/51 [1:21:25<59:00, 141.61s/it]
#
#  53%|█████▎    | 27/51 [1:24:00<58:14, 145.62s/it]
#
#  55%|█████▍    | 28/51 [1:27:30<1:03:14, 164.99s/it]
#
#  57%|█████▋    | 29/51 [1:29:22<54:40, 149.11s/it]
#
#  59%|█████▉    | 30/51 [1:30:44<45:09, 129.02s/it]
#
#  61%|██████    | 31/51 [1:32:59<43:34, 130.73s/it]
#
#  63%|██████▎   | 32/51 [1:36:49<50:48, 160.45s/it]
#
#  65%|██████▍   | 33/51 [1:38:13<41:18, 137.72s/it]
#
#  67%|██████▋   | 34/51 [1:40:03<36:35, 129.14s/it]
#
#  69%|██████▊   | 35/51 [1:41:00<28:40, 107.56s/it]
#
#  71%|███████   | 36/51 [1:43:49<31:31, 126.09s/it]
#
#  73%|███████▎  | 37/51 [1:45:00<25:34, 109.58s/it]
#
#  75%|███████▍  | 38/51 [1:46:09<21:05, 97.36s/it]
#
#  76%|███████▋  | 39/51 [1:48:47<23:06, 115.52s/it]
#
#  78%|███████▊  | 40/51 [1:50:10<19:25, 105.92s/it]
#
#  80%|████████  | 41/51 [1:51:56<17:39, 105.92s/it]
#
#  82%|████████▏ | 42/51 [1:53:15<14:40, 97.88s/it]
#
#  84%|████████▍ | 43/51 [1:55:02<13:23, 100.50s/it]
#
#  86%|████████▋ | 44/51 [1:56:48<11:54, 102.01s/it]
#
#  88%|████████▊ | 45/51 [1:57:39<08:41, 86.95s/it]
#
#  90%|█████████ | 46/51 [1:59:20<07:34, 90.93s/it]
#
#  92%|█████████▏| 47/51 [2:01:00<06:15, 93.91s/it]
#
#  94%|█████████▍| 48/51 [2:03:11<05:15, 105.03s/it]
#
#  96%|█████████▌| 49/51 [2:05:09<03:37, 108.73s/it]
#
#  98%|█████████▊| 50/51 [2:06:42<01:44, 104.17s/it]
#
# 100%|██████████| 51/51 [2:07:39<00:00, 150.19s/it]

# %%
print('STAGE 5/7')
for i in tqdm(range(204,255)):
    
    try:
        page_url = '/relatoria/providencia.aspx?pg='+ str(i) +'&buscar=&anio=&total=35718'
        main_url = root_url + page_url

        main_html_text = requests.get(main_url).text
        main_soup = BeautifulSoup(main_html_text, 'lxml')

        docs = main_soup.find_all('div', class_ = 'grow')

        for doc in docs:

            doc_link = doc.find('a')['href']

            inner_doc_url = root_url + doc_link
            html_inner_doc = requests.get(inner_doc_url).text
            inner_doc_soup = BeautifulSoup(html_inner_doc, 'lxml')

            try:
                doc_index = doc.find('a').text
                document = inner_doc_soup.find('div', class_ = 'WordSection1')
                document_text = document.text
                new_row = {'INDEX':doc_index,'LINK':inner_doc_url,'DOCUMENT':document_text}
                data_temp = data_temp.append(new_row, ignore_index=True)

            except:
                try:
                    doc_index = doc.find('a').text
                    document = inner_doc_soup.find('div', class_ = 'amplia')
                    document_text = document.text
                    new_row = {'INDEX':doc_index,'LINK':inner_doc_url,'DOCUMENT':document_text}
                    data_temp = data_temp.append(new_row, ignore_index=True)

                except Exception as e:
                    print("Error!: " + str(e))
                    print('Problema en: '+ inner_doc_url)
                    print('Pagina: ' + main_url)
                    print(' ')

    except Exception as e:
        print("Error!: " + str(e))

data = data.append(data_temp, ignore_index=True)
data_temp = pd.DataFrame(columns=['INDEX','LINK','DOCUMENT'])
# Out:
# STAGE 5/7
#   0%|          | 0/51 [00:00<?, ?it/s]
#
#   2%|▏         | 1/51 [00:58<49:05, 58.91s/it]
# Error!: ('Connection broken: OSError("(10054, \'WSAECONNRESET\')")', OSError("(10054, 'WSAECONNRESET')"))
#   4%|▍         | 2/51 [04:35<1:26:37, 106.06s/it]
#
#   6%|▌         | 3/51 [06:21<1:25:01, 106.29s/it]
#
#   8%|▊         | 4/51 [08:55<1:34:25, 120.55s/it]
#
#  10%|▉         | 5/51 [10:12<1:22:21, 107.42s/it]
#
#  12%|█▏        | 6/51 [13:56<1:46:54, 142.55s/it]
#
#  14%|█▎        | 7/51 [16:32<1:47:28, 146.56s/it]
#
#  16%|█▌        | 8/51 [18:28<1:38:18, 137.16s/it]
#
#  18%|█▊        | 9/51 [20:48<1:36:41, 138.12s/it]
#
#  20%|█▉        | 10/51 [24:18<1:49:02, 159.57s/it]
#
#  22%|██▏       | 11/51 [28:26<2:04:07, 186.19s/it]
#
#  24%|██▎       | 12/51 [31:28<2:00:17, 185.08s/it]
#
#  25%|██▌       | 13/51 [32:03<1:28:43, 140.08s/it]
#
#  27%|██▋       | 14/51 [36:13<1:46:34, 172.81s/it]
#
#  29%|██▉       | 15/51 [39:37<1:49:24, 182.35s/it]
#
#  31%|███▏      | 16/51 [43:47<1:58:08, 202.54s/it]
#
#  33%|███▎      | 17/51 [46:19<1:46:14, 187.49s/it]
#
#  35%|███▌      | 18/51 [49:41<1:45:24, 191.66s/it]
#
#  37%|███▋      | 19/51 [53:32<1:48:33, 203.54s/it]
#
#  39%|███▉      | 20/51 [57:42<1:52:20, 217.44s/it]
#
#  41%|████      | 21/51 [1:00:32<1:41:34, 203.14s/it]
#
#  43%|████▎     | 22/51 [1:03:31<1:34:46, 196.08s/it]
#
#  45%|████▌     | 23/51 [1:07:19<1:35:57, 205.61s/it]
#
#  47%|████▋     | 24/51 [1:13:11<1:52:16, 249.49s/it]
#
#  49%|████▉     | 25/51 [1:16:59<1:45:23, 243.22s/it]
#
#  51%|█████     | 26/51 [1:21:13<1:42:37, 246.29s/it]
#
#  53%|█████▎    | 27/51 [1:27:25<1:53:39, 284.16s/it]
#
#  55%|█████▍    | 28/51 [1:31:38<1:45:18, 274.73s/it]
#
#  57%|█████▋    | 29/51 [1:36:37<1:43:21, 281.89s/it]
#
#  59%|█████▉    | 30/51 [1:41:14<1:38:08, 280.38s/it]
#
#  61%|██████    | 31/51 [1:46:39<1:37:55, 293.78s/it]
#
#  63%|██████▎   | 32/51 [1:54:08<1:47:49, 340.48s/it]
#
#  65%|██████▍   | 33/51 [2:03:18<2:00:58, 403.26s/it]
#
#  67%|██████▋   | 34/51 [2:08:27<1:46:14, 374.98s/it]
#
#  69%|██████▊   | 35/51 [2:13:26<1:33:57, 352.34s/it]
#
#  71%|███████   | 36/51 [2:17:25<1:19:33, 318.26s/it]
#
#  73%|███████▎  | 37/51 [2:21:50<1:10:31, 302.27s/it]
#
#  75%|███████▍  | 38/51 [2:24:43<57:06, 263.58s/it]
#
#  76%|███████▋  | 39/51 [2:28:25<50:12, 251.00s/it]
#
#  78%|███████▊  | 40/51 [2:32:30<45:40, 249.14s/it]
#
#  80%|████████  | 41/51 [2:35:52<39:11, 235.19s/it]
#
#  82%|████████▏ | 42/51 [2:40:34<37:21, 249.08s/it]
#
#  84%|████████▍ | 43/51 [2:43:59<31:27, 235.89s/it]
#
#  86%|████████▋ | 44/51 [2:49:00<29:47, 255.33s/it]
#
#  88%|████████▊ | 45/51 [2:55:42<29:55, 299.32s/it]
#
#  90%|█████████ | 46/51 [2:58:55<22:18, 267.63s/it]
#
#  92%|█████████▏| 47/51 [3:02:31<16:47, 251.89s/it]
#
#  94%|█████████▍| 48/51 [3:05:52<11:49, 236.65s/it]
# Error!: ('Connection broken: OSError("(10054, \'WSAECONNRESET\')")', OSError("(10054, 'WSAECONNRESET')"))
#  96%|█████████▌| 49/51 [3:08:28<07:05, 212.61s/it]
# Error!: ('Connection broken: OSError("(10054, \'WSAECONNRESET\')")', OSError("(10054, 'WSAECONNRESET')"))
#  98%|█████████▊| 50/51 [3:11:13<03:18, 198.42s/it]
#
# 100%|██████████| 51/51 [3:14:56<00:00, 229.33s/it]

# %%
print('STAGE 6/7')
for i in tqdm(range(255,306)):
    
    try:
        page_url = '/relatoria/providencia.aspx?pg='+ str(i) +'&buscar=&anio=&total=35718'
        main_url = root_url + page_url

        main_html_text = requests.get(main_url).text
        main_soup = BeautifulSoup(main_html_text, 'lxml')

        docs = main_soup.find_all('div', class_ = 'grow')

        for doc in docs:

            doc_link = doc.find('a')['href']

            inner_doc_url = root_url + doc_link
            html_inner_doc = requests.get(inner_doc_url).text
            inner_doc_soup = BeautifulSoup(html_inner_doc, 'lxml')

            try:
                doc_index = doc.find('a').text
                document = inner_doc_soup.find('div', class_ = 'WordSection1')
                document_text = document.text
                new_row = {'INDEX':doc_index,'LINK':inner_doc_url,'DOCUMENT':document_text}
                data_temp = data_temp.append(new_row, ignore_index=True)

            except:
                try:
                    doc_index = doc.find('a').text
                    document = inner_doc_soup.find('div', class_ = 'amplia')
                    document_text = document.text
                    new_row = {'INDEX':doc_index,'LINK':inner_doc_url,'DOCUMENT':document_text}
                    data_temp = data_temp.append(new_row, ignore_index=True)

                except Exception as e:
                    print("Error!: " + str(e))
                    print('Problema en: '+ inner_doc_url)
                    print('Pagina: ' + main_url)
                    print(' ')

    except Exception as e:
        print("Error!: " + str(e))

data = data.append(data_temp, ignore_index=True)
data_temp = pd.DataFrame(columns=['INDEX','LINK','DOCUMENT'])

# %%
print('STAGE 7/7')
for i in tqdm(range(306,358)):
    
    try:
        page_url = '/relatoria/providencia.aspx?pg='+ str(i) +'&buscar=&anio=&total=35718'
        main_url = root_url + page_url

        main_html_text = requests.get(main_url).text
        main_soup = BeautifulSoup(main_html_text, 'lxml')

        docs = main_soup.find_all('div', class_ = 'grow')

        for doc in docs:

            doc_link = doc.find('a')['href']

            inner_doc_url = root_url + doc_link
            html_inner_doc = requests.get(inner_doc_url).text
            inner_doc_soup = BeautifulSoup(html_inner_doc, 'lxml')

            try:
                doc_index = doc.find('a').text
                document = inner_doc_soup.find('div', class_ = 'WordSection1')
                document_text = document.text
                new_row = {'INDEX':doc_index,'LINK':inner_doc_url,'DOCUMENT':document_text}
                data_temp = data_temp.append(new_row, ignore_index=True)

            except:
                try:
                    doc_index = doc.find('a').text
                    document = inner_doc_soup.find('div', class_ = 'amplia')
                    document_text = document.text
                    new_row = {'INDEX':doc_index,'LINK':inner_doc_url,'DOCUMENT':document_text}
                    data_temp = data_temp.append(new_row, ignore_index=True)

                except Exception as e:
                    print("Error!: " + str(e))
                    print('Problema en: '+ inner_doc_url)
                    print('Pagina: ' + main_url)
                    print(' ')

    except Exception as e:
        print("Error!: " + str(e))

data = data.append(data_temp, ignore_index=True)
data_temp = pd.DataFrame(columns=['INDEX','LINK','DOCUMENT'])

# %%
data_temp
# Out:
# Empty DataFrame
# Columns: [INDEX, LINK, DOCUMENT]
# Index: []

# %%
data
# Out:
#            INDEX                                               LINK  \
# 0        A107-21  https://www.corteconstitucional.gov.co/Relator...
# 1        A106-21  https://www.corteconstitucional.gov.co/Relator...
# 2        A092-21  https://www.corteconstitucional.gov.co/Relator...
# 3        A091-21  https://www.corteconstitucional.gov.co/Relator...
# 4        A090-21  https://www.corteconstitucional.gov.co/Relator...
# ...          ...                                                ...
# 25273   T-616-03  https://www.corteconstitucional.gov.co/Relator...
# 25274   T-615-03  https://www.corteconstitucional.gov.co/Relator...
# 25275   T-614-03  https://www.corteconstitucional.gov.co/Relator...
# 25276   T-613-03  https://www.corteconstitucional.gov.co/Relator...
# 25277   T-612-03  https://www.corteconstitucional.gov.co/Relator...
#
#                                                 DOCUMENT
# 0      \nAuto 107/21\n \n \nReferencia: Expediente T-...
# 1      \nAuto 106/21\n \n \nReferencia: Expediente T-...
# 2      \nAuto 092/21\n \n \nReferencia: respuesta a l...
# 3      \nAuto 091/21\n \n \nReferencia: requerimiento...
# 4      \nAuto 090/21\n \n \nReferencia: Expediente T-...
# ...                                                  ...
# 25273   \n\n\nREPUBLICA DE COLOMBIA\n\n\nSentencia T-...
# 25274   \n\n\nREPUBLICA DE COLOMBIA\n\n\nSentencia T-...
# 25275   \n\n\nREPÚBLICA DE COLOMBIA\n\n\nSentencia\r\...
# 25276   \n\n\nREPUBLICA DE COLOMBIA\n\n\nSentencia T-...
# 25277   \n\n\nREPUBLICA DE COLOMBIA\n\n\nSentencia T-...
#
# [25278 rows x 3 columns]

# %%
file_name = 'data.csv'
data.to_csv(file_name, encoding='utf-8', index= False)

# %%
data = pd.read_csv(file_name)

# %%
data
# Out:
#            INDEX                                               LINK  \
# 0        A107-21  https://www.corteconstitucional.gov.co/Relator...
# 1        A106-21  https://www.corteconstitucional.gov.co/Relator...
# 2        A092-21  https://www.corteconstitucional.gov.co/Relator...
# 3        A091-21  https://www.corteconstitucional.gov.co/Relator...
# 4        A090-21  https://www.corteconstitucional.gov.co/Relator...
# ...          ...                                                ...
# 25273   T-616-03  https://www.corteconstitucional.gov.co/Relator...
# 25274   T-615-03  https://www.corteconstitucional.gov.co/Relator...
# 25275   T-614-03  https://www.corteconstitucional.gov.co/Relator...
# 25276   T-613-03  https://www.corteconstitucional.gov.co/Relator...
# 25277   T-612-03  https://www.corteconstitucional.gov.co/Relator...
#
#                                                 DOCUMENT
# 0      \nAuto 107/21\n \n \nReferencia: Expediente T-...
# 1      \nAuto 106/21\n \n \nReferencia: Expediente T-...
# 2      \nAuto 092/21\n \n \nReferencia: respuesta a l...
# 3      \nAuto 091/21\n \n \nReferencia: requerimiento...
# 4      \nAuto 090/21\n \n \nReferencia: Expediente T-...
# ...                                                  ...
# 25273   \n\n\nREPUBLICA DE COLOMBIA\n\n\nSentencia T-...
# 25274   \n\n\nREPUBLICA DE COLOMBIA\n\n\nSentencia T-...
# 25275   \n\n\nREPÚBLICA DE COLOMBIA\n\n\nSentencia\r\...
# 25276   \n\n\nREPUBLICA DE COLOMBIA\n\n\nSentencia T-...
# 25277   \n\n\nREPUBLICA DE COLOMBIA\n\n\nSentencia T-...
#
# [25278 rows x 3 columns]

# %%
read_test = 0
