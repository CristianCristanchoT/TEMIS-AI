# %% [markdown]
# ## **Búsqueda por párrafo - Corte Constitucional**

# %% [markdown]
# ## **Importación de librerías**

# %%
import gensim
import json
import matplotlib.pyplot as plt
import nltk
import numpy as np
import os
import pandas as pd
import random
import re
import spacy

from gensim import corpora, models
from gensim.corpora.dictionary import Dictionary
from gensim.models import FastText
from gensim.models.ldamulticore import LdaMulticore
from gensim.parsing.preprocessing import STOPWORDS
from gensim.test.utils import common_texts
from gensim.test.utils import datapath
from multiprocessing import Pool
from nltk.stem import PorterStemmer 
from nltk.stem import WordNetLemmatizer 
from nltk.tokenize import sent_tokenize, word_tokenize 
from nltk.tokenize import TweetTokenizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_distances
from string import punctuation
from tqdm import tqdm
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2

# %%
nltk.download('stopwords')
nlp = spacy.load("es_core_news_md")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/caicardo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## **Definición de funciones**

# %%
ABC = 'abcdefghijklmnñopqrstuvwxyzáéíóúü0123456789 '
regex_pattern = "[^{0}{1}_]".format(ABC, ABC.upper())
sentence_regex_pattern = "[^{0}{1}_.\n]".format(ABC, ABC.upper())

# %%
def old_preprocessor(text):
    """
    preprocesador de texto
    """
    if not isinstance(text, str):
        return ""
    
    punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~ºª'''
    for char in punctuations:
        text = text.replace(char, " ")
    
    text = re.sub("\s+", " ", text)
    text = text.strip().lower()
    text = re.sub("\d+", "<NUM>", text)
    return text

# %%
def preprocessor(text):
    """
    preprocesador de texto
    """
    if not isinstance(text, str):
        return ""
    
    text = re.sub(regex_pattern, " ", text)
    text = re.sub("\s+", " ", text)
    text = text.strip().lower()
    text = re.sub("\d+", "<NUM>", text)
    return text

# %%
def preprocessor_sentences(text, debug=False):
    """
    preprocesador de texto con separación de frases por línea.
    """
    if not isinstance(text, str):
        return ""
    
    text = re.sub(sentence_regex_pattern, " ", text)
    if debug:
        print("Replace regex pattern:\n", text)
    text = re.sub("\d+", "<NUM>", text)
    if debug:
        print("Replace numbers:\n", text)
    text = text.replace("\n\n", "<FIN>")
    if debug:
        print("Tag double end_line as sentence end:\n", text)
    text = text.replace(".", "<FIN>")
    if debug:
        print("ag full stops as sentence end:\n", text)
    text = re.sub("\s+", " ", text)
    if debug:
        print("Replace whitespace for space:\n", text)
    text = text.replace("<FIN>", "\n")
    if debug:
        print("Replace line end tag for line end:\n", text)
    text = "".join([c for c in text if str.isprintable(c) or c=="\n" or c=="."])
    if debug:
        print("Remove non printable chars:\n", text)
    text = re.sub("[\n\r]+", "\n", text)
    if debug:
        print("Replace multiple line changes for a single one:\n", text)
    text = text.lower()
    if debug:
        print("Lowercase:\n", text)
    text = text.strip("\n ")
    if debug:
        print("Strip :\n", text)
    return text

# %%
def wv_vectorizer(text):
    """
    Calcula el vector promedio de las palabras de la frase.
    """
    text = preprocessor(text)
    vec_list = []
    for word in [w for w in text.split() if w not in es_stopwords]:
        vec_list.append(model.wv[word])
    if len(vec_list)==0:
        return np.random.random(model.wv.vector_size)
    vec_list = np.array(vec_list)
    norms = np.linalg.norm(vec_list, axis=1).reshape(-1,1)
    norms = np.array([n if n>0 else 1.0 for n in norms])
    vec_over_norm = vec_list/norms
    vec = np.mean(vec_over_norm, axis=0)
    return vec

# %%
def remove_stopwords(text):
    tokens = text.split()
    out = " ".join([word for word in tokens if word not in es_stopwords])
    return out

# %%
def lemmatize(text):
    nlp_tokens = nlp(text)
    lemma = [w.lemma_ for w in nlp_tokens]
    lemma = " ".join(lemma)
    return lemma

# %%
def transform_token(token):
    if token.is_stop:
        return "<STOP>" + token.text
    if token.pos_!= 'PROPN':
        return token.lemma_
    return token.text


def full_preprocess(text, debug=False):
    """
    Performs lemmatization, stopword removal via spacy and custom list and preprocessing
    """
    text = re.sub("\s+", " ", text)
    nlp_tokens = nlp(text)
    mask = [w.pos_ for w in nlp_tokens]
    spacy_pp = [transform_token(w) for w in nlp_tokens]

    joint_spp = spacy_pp[0]
    for i in range(1, len(mask)):
        joint_spp = "".join([joint_spp, "_" if (mask[i]=='PROPN' and mask[i-1]=='PROPN') else " ", spacy_pp[i]])

    joint_spp = " ".join([w for w in joint_spp.split() if not w.startswith("<STOP>")])

    preprocessed = preprocessor(joint_spp)

    out = remove_stopwords(preprocessed)
    return out

# %% [markdown]
# ## **Configuración**

# %%
RANDOM_STATE = 42
N_TOP_DOCS = 5
CARACTERES = 500

# %%
random.seed(RANDOM_STATE)
np.random.seed(RANDOM_STATE)

# %%
# DATA_PATH = './scrappy/'
DATA_PATH = "data/cc_dump_p.csv"

# %%
es_stopwords = nltk.corpus.stopwords.words("spanish")

# %%
es_stopwords.remove("no")

# %%
es_stopwords.append("<NUM>")

# %% [markdown]
# ## **Lectura de datos**

# %%
df = pd.read_csv(DATA_PATH)

# %%
df.rename({"class":"class_", "name":"sentencia"}, axis=1, inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0  p_index tag                                               text  \
# 0           0        0  h5                                 Sentencia T-120/05
# 1           1        2   p  PROPIEDAD HORIZONTAL-Obligaciones a cargo de l...
# 2           2        4   p  ADMINISTRACION DE PROPIEDAD HORIZONTAL-No pago...
# 3           3        6   p  CUOTAS DE ADMINISTRACION-Compra de inmueble en...
# 4           4        9   p                    Referencia: expediente T-992178
#
#       class_ sentencia                         link
# 0   no_class  T-120-05  Relatoria/2005/T-120-05.htm
# 1  MsoNormal  T-120-05  Relatoria/2005/T-120-05.htm
# 2  MsoNormal  T-120-05  Relatoria/2005/T-120-05.htm
# 3  MsoNormal  T-120-05  Relatoria/2005/T-120-05.htm
# 4  MsoNormal  T-120-05  Relatoria/2005/T-120-05.htm

# %%
len(df)
# Out:
# 6587045

# %%
df = df[[isinstance(x, str) for x in df.text.values]]

# %%
len(df)
# Out:
# 6586593

# %% [markdown]
# ## **Revisión para separación por frases de cada párrafo**

# %%
id_ejemplo = 1111

# %%
print("Original:\n", df.iloc[id_ejemplo].text)
# Out:
# Original:
#  De la misma manera, el Juzgado demandado
# afirma que la decisión de la Comisaría de Familia en la que se sanciona al
# señor Jesús Arnulfo Grandas Duarte no podría tenerse en cuenta por cuanto
# considera que la actuación de la entidad no fue la correcta. Al respecto se
# reitera que aunque el trámite correcto no haya sido decretar de nuevo una
# medida de protección provisional, tampoco podría por tal motivo desconocer que
# el señor Grandas Duarte había incurrido de nuevo en actos violentos contra la
# accionante y establecer arbitrariamente que no había incumplido la medida de
# protección de 24 de septiembre de 2012, dejando no solo sin sanción al
# demandado sino sin protección y en estado de vulneración a la señora Nubia
# Mercedes Mateus Hernández.

# %%
preprocessor_sentences(df.iloc[id_ejemplo].text, debug=True)
# Out:
# Replace regex pattern:
#  De la misma manera  el Juzgado demandado
# afirma que la decisión de la Comisaría de Familia en la que se sanciona al
# señor Jesús Arnulfo Grandas Duarte no podría tenerse en cuenta por cuanto
# considera que la actuación de la entidad no fue la correcta. Al respecto se
# reitera que aunque el trámite correcto no haya sido decretar de nuevo una
# medida de protección provisional  tampoco podría por tal motivo desconocer que
# el señor Grandas Duarte había incurrido de nuevo en actos violentos contra la
# accionante y establecer arbitrariamente que no había incumplido la medida de
# protección de 24 de septiembre de 2012  dejando no solo sin sanción al
# demandado sino sin protección y en estado de vulneración a la señora Nubia
# Mercedes Mateus Hernández.
# Replace numbers:
#  De la misma manera  el Juzgado demandado
# afirma que la decisión de la Comisaría de Familia en la que se sanciona al
# señor Jesús Arnulfo Grandas Duarte no podría tenerse en cuenta por cuanto
# considera que la actuación de la entidad no fue la correcta. Al respecto se
# reitera que aunque el trámite correcto no haya sido decretar de nuevo una
# medida de protección provisional  tampoco podría por tal motivo desconocer que
# el señor Grandas Duarte había incurrido de nuevo en actos violentos contra la
# accionante y establecer arbitrariamente que no había incumplido la medida de
# protección de <NUM> de septiembre de <NUM>  dejando no solo sin sanción al
# demandado sino sin protección y en estado de vulneración a la señora Nubia
# Mercedes Mateus Hernández.
# Tag double end_line as sentence end:
#  De la misma manera  el Juzgado demandado
# afirma que la decisión de la Comisaría de Familia en la que se sanciona al
# señor Jesús Arnulfo Grandas Duarte no podría tenerse en cuenta por cuanto
# considera que la actuación de la entidad no fue la correcta. Al respecto se
# reitera que aunque el trámite correcto no haya sido decretar de nuevo una
# medida de protección provisional  tampoco podría por tal motivo desconocer que
# el señor Grandas Duarte había incurrido de nuevo en actos violentos contra la
# accionante y establecer arbitrariamente que no había incumplido la medida de
# protección de <NUM> de septiembre de <NUM>  dejando no solo sin sanción al
# demandado sino sin protección y en estado de vulneración a la señora Nubia
# Mercedes Mateus Hernández.
# ag full stops as sentence end:
#  De la misma manera  el Juzgado demandado
# afirma que la decisión de la Comisaría de Familia en la que se sanciona al
# señor Jesús Arnulfo Grandas Duarte no podría tenerse en cuenta por cuanto
# considera que la actuación de la entidad no fue la correcta<FIN> Al respecto se
# reitera que aunque el trámite correcto no haya sido decretar de nuevo una
# medida de protección provisional  tampoco podría por tal motivo desconocer que
# el señor Grandas Duarte había incurrido de nuevo en actos violentos contra la
# accionante y establecer arbitrariamente que no había incumplido la medida de
# protección de <NUM> de septiembre de <NUM>  dejando no solo sin sanción al
# demandado sino sin protección y en estado de vulneración a la señora Nubia
# Mercedes Mateus Hernández<FIN>
# Replace whitespace for space:
#  De la misma manera el Juzgado demandado afirma que la decisión de la Comisaría de Familia en la que se sanciona al señor Jesús Arnulfo Grandas Duarte no podría tenerse en cuenta por cuanto considera que la actuación de la entidad no fue la correcta<FIN> Al respecto se reitera que aunque el trámite correcto no haya sido decretar de nuevo una medida de protección provisional tampoco podría por tal motivo desconocer que el señor Grandas Duarte había incurrido de nuevo en actos violentos contra la accionante y establecer arbitrariamente que no había incumplido la medida de protección de <NUM> de septiembre de <NUM> dejando no solo sin sanción al demandado sino sin protección y en estado de vulneración a la señora Nubia Mercedes Mateus Hernández<FIN>
# Replace line end tag for line end:
#  De la misma manera el Juzgado demandado afirma que la decisión de la Comisaría de Familia en la que se sanciona al señor Jesús Arnulfo Grandas Duarte no podría tenerse en cuenta por cuanto considera que la actuación de la entidad no fue la correcta
#  Al respecto se reitera que aunque el trámite correcto no haya sido decretar de nuevo una medida de protección provisional tampoco podría por tal motivo desconocer que el señor Grandas Duarte había incurrido de nuevo en actos violentos contra la accionante y establecer arbitrariamente que no había incumplido la medida de protección de <NUM> de septiembre de <NUM> dejando no solo sin sanción al demandado sino sin protección y en estado de vulneración a la señora Nubia Mercedes Mateus Hernández
#
# Remove non printable chars:
#  De la misma manera el Juzgado demandado afirma que la decisión de la Comisaría de Familia en la que se sanciona al señor Jesús Arnulfo Grandas Duarte no podría tenerse en cuenta por cuanto considera que la actuación de la entidad no fue la correcta
#  Al respecto se reitera que aunque el trámite correcto no haya sido decretar de nuevo una medida de protección provisional tampoco podría por tal motivo desconocer que el señor Grandas Duarte había incurrido de nuevo en actos violentos contra la accionante y establecer arbitrariamente que no había incumplido la medida de protección de <NUM> de septiembre de <NUM> dejando no solo sin sanción al demandado sino sin protección y en estado de vulneración a la señora Nubia Mercedes Mateus Hernández
#
# Replace multiple line changes for a single one:
#  De la misma manera el Juzgado demandado afirma que la decisión de la Comisaría de Familia en la que se sanciona al señor Jesús Arnulfo Grandas Duarte no podría tenerse en cuenta por cuanto considera que la actuación de la entidad no fue la correcta
#  Al respecto se reitera que aunque el trámite correcto no haya sido decretar de nuevo una medida de protección provisional tampoco podría por tal motivo desconocer que el señor Grandas Duarte había incurrido de nuevo en actos violentos contra la accionante y establecer arbitrariamente que no había incumplido la medida de protección de <NUM> de septiembre de <NUM> dejando no solo sin sanción al demandado sino sin protección y en estado de vulneración a la señora Nubia Mercedes Mateus Hernández
#
# Lowercase:
#  de la misma manera el juzgado demandado afirma que la decisión de la comisaría de familia en la que se sanciona al señor jesús arnulfo grandas duarte no podría tenerse en cuenta por cuanto considera que la actuación de la entidad no fue la correcta
#  al respecto se reitera que aunque el trámite correcto no haya sido decretar de nuevo una medida de protección provisional tampoco podría por tal motivo desconocer que el señor grandas duarte había incurrido de nuevo en actos violentos contra la accionante y establecer arbitrariamente que no había incumplido la medida de protección de <num> de septiembre de <num> dejando no solo sin sanción al demandado sino sin protección y en estado de vulneración a la señora nubia mercedes mateus hernández
#
# Strip :
#  de la misma manera el juzgado demandado afirma que la decisión de la comisaría de familia en la que se sanciona al señor jesús arnulfo grandas duarte no podría tenerse en cuenta por cuanto considera que la actuación de la entidad no fue la correcta
#  al respecto se reitera que aunque el trámite correcto no haya sido decretar de nuevo una medida de protección provisional tampoco podría por tal motivo desconocer que el señor grandas duarte había incurrido de nuevo en actos violentos contra la accionante y establecer arbitrariamente que no había incumplido la medida de protección de <num> de septiembre de <num> dejando no solo sin sanción al demandado sino sin protección y en estado de vulneración a la señora nubia mercedes mateus hernández
# 'de la misma manera el juzgado demandado afirma que la decisión de la comisaría de familia en la que se sanciona al señor jesús arnulfo grandas duarte no podría tenerse en cuenta por cuanto considera que la actuación de la entidad no fue la correcta\n al respecto se reitera que aunque el trámite correcto no haya sido decretar de nuevo una medida de protección provisional tampoco podría por tal motivo desconocer que el señor grandas duarte había incurrido de nuevo en actos violentos contra la accionante y establecer arbitrariamente que no había incumplido la medida de protección de <num> de septiembre de <num> dejando no solo sin sanción al demandado sino sin protección y en estado de vulneración a la señora nubia mercedes mateus hernández'

# %%
preprocessor_sentences(df.iloc[id_ejemplo].text).split('\n')
# Out:
# ['de la misma manera el juzgado demandado afirma que la decisión de la comisaría de familia en la que se sanciona al señor jesús arnulfo grandas duarte no podría tenerse en cuenta por cuanto considera que la actuación de la entidad no fue la correcta',
#  ' al respecto se reitera que aunque el trámite correcto no haya sido decretar de nuevo una medida de protección provisional tampoco podría por tal motivo desconocer que el señor grandas duarte había incurrido de nuevo en actos violentos contra la accionante y establecer arbitrariamente que no había incumplido la medida de protección de <num> de septiembre de <num> dejando no solo sin sanción al demandado sino sin protección y en estado de vulneración a la señora nubia mercedes mateus hernández']

# %% [markdown]
# ## **Crear corpus preprocesado para FastText**

# %% [markdown]
# #### **Preprocesamiento de texto (para TF-IDF)**
#
# Como el preprocesamiento no toma tanto tiempo, no hay problema en repetirlo, pero en general no es necesario volver a preprocesar los datos, se pueden guardar descomentando el código más abajo.

# %%
# %%time
with Pool(8) as my_pool:
    pp_list = my_pool.map(preprocessor_sentences, df.text.values)
# Out:
# CPU times: user 10 s, sys: 5.65 s, total: 15.7 s
# Wall time: 1min

# %%
df["pp"] = pp_list

# %%
df.head()
# Out:
#    Unnamed: 0  p_index tag                                               text  \
# 0           0        0  h5                                 Sentencia T-120/05
# 1           1        2   p  PROPIEDAD HORIZONTAL-Obligaciones a cargo de l...
# 2           2        4   p  ADMINISTRACION DE PROPIEDAD HORIZONTAL-No pago...
# 3           3        6   p  CUOTAS DE ADMINISTRACION-Compra de inmueble en...
# 4           4        9   p                    Referencia: expediente T-992178
#
#       class_ sentencia                         link  \
# 0   no_class  T-120-05  Relatoria/2005/T-120-05.htm
# 1  MsoNormal  T-120-05  Relatoria/2005/T-120-05.htm
# 2  MsoNormal  T-120-05  Relatoria/2005/T-120-05.htm
# 3  MsoNormal  T-120-05  Relatoria/2005/T-120-05.htm
# 4  MsoNormal  T-120-05  Relatoria/2005/T-120-05.htm
#
#                                                   pp
# 0                            sentencia t <num> <num>
# 1  propiedad horizontal obligaciones a cargo de l...
# 2  administracion de propiedad horizontal no pago...
# 3  cuotas de administracion compra de inmueble en...
# 4                      referencia expediente t <num>

# %% [markdown]
# ## Stats

# %%
print("Cantidad de documentos: {}".format(len(df.sentencia.unique())))
# Out:
# Cantidad de documentos: 34932

# %%
df["word_count"] = [len(x.strip().split()) for x in df.text.values]

# %%
max_wc = np.max(df.word_count)
max_wc_p = df[df.word_count==max_wc].iloc[0].to_dict()
print("Características del párrafo más largo:")
print("- párrafo {0} de la sentencia {1}.".format(max_wc_p["p_index"], max_wc_p["sentencia"]))
print("- Contiene {} palabras.".format(max_wc_p["word_count"]))
# Out:
# Características del párrafo más largo:
# - párrafo 22 de la sentencia T-1532-00.
# - Contiene 7456 palabras.

# %%
df["class_"] = pd.Categorical(df["class_"])

# %%
df["class_"].value_counts()
# Out:
# MsoNormal           4550691
# MsoFootnoteText      761740
# MsoBodyText          235933
# no_class             139539
# MsoListParagraph      84887
#                      ...
# ecxecxbodytext2           1
# ecmsobodytext             1
# decretos                  1
# de                        1
# yiv8754979524             1
# Name: class_, Length: 1357, dtype: int64

# %% [markdown]
# ## **Preprocesamiento de texto (para TF-IDF)**
#
# Como el preprocesamiento no toma tanto tiempo, no hay problema en repetirlo, pero en general no es necesario volver a preprocesar los datos, se pueden guardar descomentando el código más abajo.

# %%
# %%time
with Pool(8) as my_pool:
    pp_list = my_pool.map(full_preprocess, df.text.values)
# Out:
# CPU times: user 9.75 s, sys: 9.43 s, total: 19.2 s
# Wall time: 2h 3min 25s

# %%
df["pp"] = pp_list

# %%
df.head()
# Out:
#    Unnamed: 0  p_index tag                                               text  \
# 0           0        0  h5                                 Sentencia T-120/05
# 1           1        2   p  PROPIEDAD HORIZONTAL-Obligaciones a cargo de l...
# 2           2        4   p  ADMINISTRACION DE PROPIEDAD HORIZONTAL-No pago...
# 3           3        6   p  CUOTAS DE ADMINISTRACION-Compra de inmueble en...
# 4           4        9   p                    Referencia: expediente T-992178
#
#       class_ sentencia                         link  word_count  \
# 0   no_class  T-120-05  Relatoria/2005/T-120-05.htm           2
# 1  MsoNormal  T-120-05  Relatoria/2005/T-120-05.htm          27
# 2  MsoNormal  T-120-05  Relatoria/2005/T-120-05.htm          10
# 3  MsoNormal  T-120-05  Relatoria/2005/T-120-05.htm          14
# 4  MsoNormal  T-120-05  Relatoria/2005/T-120-05.htm           3
#
#                                                   pp
# 0                                        sentencia_t
# 1  propiedad_horizontal obligaciones cargo propie...
# 2  administracion propiedad_horizontal no pago cu...
# 3  cuotas administracion compra inmueble remate d...
# 4                            referencia expediente t

# %% [markdown]
# **Guardar datos preprocesados**

# %%
df.to_csv("data/cc_dump_full_pp_20210508.csv")

# %% [markdown]
# ## Para datos ya preprocesados, empezar acá

# %%
df = pd.read_csv("data/cc_dump_full_pp_20210508.csv")

# %%
len(df)
# Out:
# 6586593

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  p_index tag  \
# 0           0             0        0  h5
# 1           1             1        2   p
# 2           2             2        4   p
# 3           3             3        6   p
# 4           4             4        9   p
#
#                                                 text     class_ sentencia  \
# 0                                 Sentencia T-120/05   no_class  T-120-05
# 1  PROPIEDAD HORIZONTAL-Obligaciones a cargo de l...  MsoNormal  T-120-05
# 2  ADMINISTRACION DE PROPIEDAD HORIZONTAL-No pago...  MsoNormal  T-120-05
# 3  CUOTAS DE ADMINISTRACION-Compra de inmueble en...  MsoNormal  T-120-05
# 4                    Referencia: expediente T-992178  MsoNormal  T-120-05
#
#                           link  word_count  \
# 0  Relatoria/2005/T-120-05.htm           2
# 1  Relatoria/2005/T-120-05.htm          27
# 2  Relatoria/2005/T-120-05.htm          10
# 3  Relatoria/2005/T-120-05.htm          14
# 4  Relatoria/2005/T-120-05.htm           3
#
#                                                   pp
# 0                                        sentencia_t
# 1  propiedad_horizontal obligaciones cargo propie...
# 2  administracion propiedad_horizontal no pago cu...
# 3  cuotas administracion compra inmueble remate d...
# 4                            referencia expediente t

# %% [markdown]
# #### Ejemplo preproceso

# %%
# Ejemplo
id_ejemplo = 687
print("Original:\n{}".format(df.iloc[id_ejemplo].text))
print("-*"*20)
print("Preprocesado:\n{}".format(df.iloc[id_ejemplo].pp))
print("-*"*20)
print("Quitar palabras vacías (stop words):\n{}".format(remove_stopwords(df.iloc[id_ejemplo].pp)))
print("-*"*20)
print("Lematización:\n{}".format(lemmatize(remove_stopwords(df.iloc[id_ejemplo].pp))))
print("-*"*20)
print("Full Preprocess:\n{}".format(full_preprocess(df.iloc[id_ejemplo].text)))
print("-*"*20)
print("Full Preprocess debug:\n{}".format(full_preprocess(df.iloc[id_ejemplo].text, debug=True)))
# Out:
# Original:
# 16- La Corte destaca
# que el anterior análisis es compatible con los criterios desarrollados en la
# sentencia C-215 de 1999, MP Martha Victoria Sáchica de Moncaleano, citada por
# el actor y por varios de los intervinientes para sustentar la
# inconstitucionalidad del término de prescripción consagrado por la norma
# acusada.  Así, esa providencia declaró la inconstitucionalidad del término de
# caducidad establecido por el artículo 11 de la Ley 472 de 1998, según el cual,
# la acción popular caducaba en 5 años cuando estaba dirigida a volver las cosas
# a su estado anterior. El argumento central de la Corte fue que no se justifica un
# término de caducidad, “mientras subsista la vulneración a un derecho o interés
# colectivo y exista la posibilidad de volver las cosas al estado anterior para
# hacer cesar esa violación”, pues en tal evento debe entenderse que “cualquiera
# de los miembros del grupo social debe tener la oportunidad de acudir a la
# justicia, para obtener esa protección”. Nótese pues que en el caso de la acción
# popular, la vulneración del interés colectivo subsiste, y existe además la
# posibilidad de retrotraer las cosas a su estado inicial, por lo cual, el
# término de caducidad resultaba injustificado. En cambio, en el caso del fuero
# sindical, la prescripción se justifica, no sólo por razones de seguridad
# jurídica sino por el sentido mismo que tiene el fuero sindical. En efecto, la
# imprescriptibilidad de las reclamaciones del trabajador aforado podría hacer
# perder su significado al fuero sindical, que es proteger el derecho de
# asociación, pues ¿qué beneficio tiene para la libertad sindical reintegrar a un
# trabajador treinta años después de ocurridos los hechos?.
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# Preprocesado:
# corte destacar análisis compatible criterio desarrollado sentencia c mp_martha_victoria_sáchica moncaleano citado actor intervinient sustentar inconstitucionalidad término prescripción consagrado norma acusado providencia declarar inconstitucionalidad término caducidad establecido artículo ley acción popular caducar año dirigido volver argumento central corte justificar término caducidad subsistir vulneración derecho interés colectivo existir posibilidad volver cesar violación evento entender cualquiera miembro grupo social oportunidad acudir justicia obtener protección nótese caso acción popular vulneración interés colectivo subsistir posibilidad retrotraer inicial término caducidad resultar injustificado cambio caso fuero sindical prescripción justificar razón seguridad jurídico fuero sindical efecto imprescriptibilidad reclamación trabajador aforado perder significado fuero sindical proteger derecho asociación beneficio libertad sindical reintegrar trabajador treinta año ocurrido hecho
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# Quitar palabras vacías (stop words):
# corte destacar análisis compatible criterio desarrollado sentencia c mp_martha_victoria_sáchica moncaleano citado actor intervinient sustentar inconstitucionalidad término prescripción consagrado norma acusado providencia declarar inconstitucionalidad término caducidad establecido artículo ley acción popular caducar año dirigido volver argumento central corte justificar término caducidad subsistir vulneración derecho interés colectivo existir posibilidad volver cesar violación evento entender cualquiera miembro grupo social oportunidad acudir justicia obtener protección nótese caso acción popular vulneración interés colectivo subsistir posibilidad retrotraer inicial término caducidad resultar injustificado cambio caso fuero sindical prescripción justificar razón seguridad jurídico fuero sindical efecto imprescriptibilidad reclamación trabajador aforado perder significado fuero sindical proteger derecho asociación beneficio libertad sindical reintegrar trabajador treinta año ocurrido hecho
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# Lematización:
# corte destacar análisis compatible criterio desarrollado sentencia c mp_martha_victoria_sáchico moncaleano citado actor intervinient sustentar inconstitucionalidad término prescripción consagrado norma acusado providencia declarar inconstitucionalidad término caducidad establecido artículo ley acción popular caducar año dirigido volver argumento central corte justificar término caducidad subsistir vulneración derecho interés colectivo existir posibilidad volver cesar violación evento entender cualquiera miembro grupo social oportunidad acudir justicia obtener protección nótese caso acción popular vulneración interés colectivo subsistir posibilidad retrotraer inicial término caducidad resultar injustificado cambio caso fuero sindical prescripción justificar razón seguridad jurídico fuero sindical efecto imprescriptibilidad reclamación trabajador aforado perder significado fuero sindical proteger derecho asociación beneficio libertad sindical reintegrar trabajador treinta año ocurrido hecho
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# Full Preprocess:
# corte destacar análisis compatible criterio desarrollado sentencia c mp_martha_victoria_sáchica moncaleano citado actor intervinient sustentar inconstitucionalidad término prescripción consagrado norma acusado providencia declarar inconstitucionalidad término caducidad establecido artículo ley acción popular caducar año dirigido volver argumento central corte justificar término caducidad subsistir vulneración derecho interés colectivo existir posibilidad volver cesar violación evento entender cualquiera miembro grupo social oportunidad acudir justicia obtener protección nótese caso acción popular vulneración interés colectivo subsistir posibilidad retrotraer inicial término caducidad resultar injustificado cambio caso fuero sindical prescripción justificar razón seguridad jurídico fuero sindical efecto imprescriptibilidad reclamación trabajador aforado perder significado fuero sindical proteger derecho asociación beneficio libertad sindical reintegrar trabajador treinta año ocurrido hecho
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# Full Preprocess debug:
# corte destacar análisis compatible criterio desarrollado sentencia c mp_martha_victoria_sáchica moncaleano citado actor intervinient sustentar inconstitucionalidad término prescripción consagrado norma acusado providencia declarar inconstitucionalidad término caducidad establecido artículo ley acción popular caducar año dirigido volver argumento central corte justificar término caducidad subsistir vulneración derecho interés colectivo existir posibilidad volver cesar violación evento entender cualquiera miembro grupo social oportunidad acudir justicia obtener protección nótese caso acción popular vulneración interés colectivo subsistir posibilidad retrotraer inicial término caducidad resultar injustificado cambio caso fuero sindical prescripción justificar razón seguridad jurídico fuero sindical efecto imprescriptibilidad reclamación trabajador aforado perder significado fuero sindical proteger derecho asociación beneficio libertad sindical reintegrar trabajador treinta año ocurrido hecho

# %% [markdown]
# ### Verificaciones de textos vacíos

# %%
df[df.text.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, p_index, tag, text, class_, sentencia, link, pp]
# Index: []

# %%
df[df.pp==""]
# Out:
#          Unnamed: 0  p_index tag   text     class_ sentencia  \
# 205             205      123   p    (…)  MsoNormal  T-515-06
# 597             597       95   p  (...)  MsoNormal  C-381-00
# 601             601      103   p   (…)   MsoNormal  C-381-00
# 671             671      246   p    (…)  MsoNormal  C-381-00
# 1078           1078      642   p    (…)  MsoNormal  T-241-16
# ...             ...      ...  ..    ...        ...       ...
# 6585162     6585162      731   p      “  MsoNormal  C-753-08
# 6585163     6585163      732   p  (...)  MsoNormal  C-753-08
# 6585193     6585193      785   p    (…)  MsoNormal  C-753-08
# 6585299     6585299      957   p  (...)  MsoNormal  C-753-08
# 6586301     6586301      898   p  (...)  MsoNormal  C-307-20
#
#                                 link pp
# 205      Relatoria/2006/T-515-06.htm
# 597      Relatoria/2000/C-381-00.htm
# 601      Relatoria/2000/C-381-00.htm
# 671      Relatoria/2000/C-381-00.htm
# 1078     Relatoria/2016/T-241-16.htm
# ...                              ... ..
# 6585162  Relatoria/2008/C-753-08.htm
# 6585163  Relatoria/2008/C-753-08.htm
# 6585193  Relatoria/2008/C-753-08.htm
# 6585299  Relatoria/2008/C-753-08.htm
# 6586301  Relatoria/2020/C-307-20.htm
#
# [37406 rows x 8 columns]

# %%
df = df[df.pp.notnull()].copy()

# %%
len(df)
# Out:
# 6586593

# %%
df[~np.array([isinstance(x, str) for x in df.pp.values])]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, p_index, tag, text, class_, sentencia, link, pp]
# Index: []

# %%
df = df[[isinstance(x, str) for x in df.pp.values]].copy()

# %% [markdown]
# ## **Entrenamiento de vectores de palabras**

# %% [markdown]
# No es necesario entrenar el modelo con el corpus cada vez que se ejecute el libro, pasar a "cargar modelo"

# %% [markdown]
# **Prueba Segmentación por frases**

# %%
for i, frase in enumerate([frase for frase in df.iloc[11111].pp.split("\n")]):
    print("{0}. {1}".format(i, frase))
# Out:
# 0. si bien es cierto que las pruebas allegadas al expediente indican que el municipio durante el tiempo que el accionante laboró para éste no hizo cotización para pensiones <num> es claro que esto no implica que el accionante no tuviera derecho a sus prestaciones sociales
# 1.  desde la expedición de la ley <num> de <num> se determinó que era obligación del patrono responder por las prestaciones sociales para con sus empleados mientras se creaba el sistema de seguridad social correspondiente para el caso
# 2.  para la fecha en la cual el accionante trabajó con el municipio las entidades territoriales tenían la autonomía para determinar la forma en la cual respondían por las prestaciones sociales de la cual los empleados eran acreedores de acuerdo con la legislación nacional
# 3.  de forma que el que no se hubieran hecho las contingencias necesarias para responder por estas obligaciones en un futuro no significa que el municipio pueda desconocer la obligación que se tiene con los derechos adquiridos del trabajador
# 4.  adicionalmente es claro que en virtud del decreto <num> de <num> <num> en los casos en los cuales el empleado oficial no estuviere afiliado a ninguna entidad de previsión social el reconocimiento de la prestación corre por cuenta de la última entidad o empresa social empleadora

# %% [markdown]
# **Guardar Corpus de documentos segmentados por frase**

# %%
VERSION = '0.1'
corpus_path = f"data/corpus/corpus_cc_p_v{VERSION}.txt"
model_path = f"models/cc_model_{VERSION}.vec"

# %%
with open(corpus_path, "w") as file:
    for doc in df.pp.values:
        file.write(preprocessor_sentences(doc))
        file.write("\n")

# %%
carpeta = os.getcwd()
direccion_corpus = os.path.join(carpeta, corpus_path)

# %%
corpus_file = datapath(direccion_corpus)         # absolute path to corpus
model = FastText(size=100, 
                 window=5, 
                 min_count=5, 
                 workers=-1, 
                 seed=RANDOM_STATE)
model.build_vocab(corpus_file=corpus_file)      # scan over corpus to build the vocabulary
total_words = model.corpus_total_words          # number of words in the corpus
model.train(corpus_file=corpus_file, total_words=total_words, epochs=5)

# %% [markdown]
# **Guardar modelo**

# %%
model.save(model_path)

# %% [markdown]
# **Cargar modelo**

# %%
model = FastText.load(model_path)

# %%
# %%time
with Pool(8) as my_pool:
    pp_ns_list = my_pool.map(remove_stopwords, df.pp.values)
# df["pp_sin_stop"] = [" ".join([w for w in doc.split() if w not in es_stopwords]) for doc in df.pp.values]
df["pp_sin_stop"] = pp_ns_list
# Out:
# CPU times: user 7.22 s, sys: 5.25 s, total: 12.5 s
# Wall time: 1min 44s

# %% [markdown]
# ## **Calcular vectores de las frases y los documentos**

# %% [markdown]
# **Entrenar vectores de documentos**

# %%
df = df[df.pp_sin_stop.notnull()].copy()

# %%
# %%time
with Pool(8) as poo:
    vectors = poo.map(wv_vectorizer, df.pp_sin_stop.values)

df["vec"] = vectors

# %%
df["is_vec"] = [isinstance(x, np.ndarray) for x in df.vec.values]

# %%
df = df[df.is_vec].copy()

# %%
doc_vectors = np.array([x for x in df.vec.values])
# doc_vectors = df.vec.values

# %% [markdown]
# **Guardar documentos con vectores**

# %%
df.to_csv("data/paragraph_vectors_v0.1.csv")

# %% [markdown]
# **Cálculo de vector de la frase**

# %%
# frase = "pensión de sobreviviente decreto 2728 de 1969"
# frase = "falsos positivos"
# frase = "protección al adulto mayor"
# frase = "pensión de supervivencia"
frase = "consulta previa"

# %%
# calcular el vector de la frase
phrase_vec = wv_vectorizer(frase)

# %%
phrase_vec
# Out:
# array([ 2.97301827e-04, -4.65764519e-04,  1.11971307e-03,  1.22255436e-03,
#        -5.45769464e-04, -1.59656839e-03,  1.27970660e-03, -8.91659874e-06,
#        -1.42677245e-03,  8.97148508e-04,  4.46662598e-04,  2.26835255e-07,
#         6.25719549e-04, -2.41074653e-04,  7.53106549e-04, -1.06092193e-05,
#         1.49572105e-03, -7.72974454e-05, -3.01099615e-04, -1.40991807e-03,
#        -7.12837151e-04, -1.42041827e-03, -5.37425687e-04,  1.25699688e-03,
#         4.42318997e-05,  1.77840656e-03,  4.09775937e-04, -2.56820145e-04,
#         7.42649718e-05,  9.07317968e-04,  2.70076620e-04,  1.29609334e-03,
#        -2.19161808e-03, -1.29044312e-03, -9.98578267e-04,  2.23540083e-05,
#        -4.58189170e-04, -3.92740243e-04,  1.49848624e-04,  1.73890061e-04,
#         1.02566276e-03,  9.66676569e-04, -2.99500214e-04, -1.38425094e-04,
#         4.36541712e-04,  8.85375193e-05, -6.07508002e-04, -2.96541693e-04,
#         4.87942802e-04,  2.41167494e-04,  7.16924318e-04,  5.67397336e-04,
#        -2.13149731e-04,  2.15319730e-03,  6.83928782e-04,  1.82636664e-04,
#        -3.97006050e-04,  8.98220344e-04,  2.92462501e-05,  2.45258794e-04,
#         1.78081158e-04,  1.62224809e-03,  8.74110556e-05, -4.62375290e-04,
#         1.53798668e-04, -8.85011221e-04,  5.22838789e-04, -2.03403342e-03,
#        -1.50533649e-03,  5.67617826e-06,  3.11360374e-04, -6.65551051e-04,
#         9.56527656e-04, -2.89807242e-04,  1.77303780e-04,  3.76174925e-04,
#        -1.16825057e-03, -1.98889524e-03, -3.21527303e-04,  1.72780745e-03,
#        -1.03283394e-03, -6.61261554e-04, -2.28150166e-04, -2.62389635e-03,
#        -4.91778948e-04,  2.94634752e-04,  9.89958644e-04, -6.20344887e-04,
#        -4.42495308e-04,  8.72051634e-04, -5.97152743e-04,  3.08459508e-04,
#        -2.24047835e-04, -7.11743021e-04, -8.14271742e-04, -1.81880212e-04,
#        -4.00260556e-04, -1.13533126e-04,  4.67102014e-04, -3.04468762e-04],
#       dtype=float32)

# %%
# %%time
# Calcular distancia de la frase a los documentos
distances = cosine_distances(phrase_vec.reshape(1, -1), doc_vectors)
# distances = cosine_distances(phrase_vec, doc_vectors)
# Out:
# CPU times: user 4.08 s, sys: 5.38 s, total: 9.46 s
# Wall time: 7.23 s

# %%
distances = distances.flatten()

# %%
top_docs_full = np.argsort(distances, )
print(top_docs_full[0])
sorted_distances = np.sort(distances)
print(sorted_distances[0])
# Out:
# 4143735
# 1.1102230246251565e-16

# %%
np.sum(sorted_distances<0.10)
# Out:
# 22

# %%
THRESHOLD_SIM = 0.90
N_TOP_DOCS = len(df.iloc[top_docs_full[:np.sum(sorted_distances<(1-THRESHOLD_SIM))]].sentencia.unique())

# %%
print(N_TOP_DOCS)

size = N_TOP_DOCS

while len(df.iloc[top_docs_full[:size]].sentencia.unique()) < N_TOP_DOCS:
    size += 1
top_docs = top_docs_full[:size]
top_dist = sorted_distances[:size]
# Out:
# 17

# %%
top_sentencias = df.iloc[top_docs].sentencia.unique()

# %%
top_sentencias
# Out:
# array(['T-733-17', 'T-236-17', 'SU123-18', 'C-154-16', 'C-020-18',
#        'C-098-20', 'C-494-19', 'SU111-20', 'C-025-18', 'T-576-14',
#        'C-252-19', 'C-491-19', 'T-247-15', 'T-011-18', 'T-568-17',
#        'C-1051-12', 'T-348-12'], dtype=object)

# %%
top_p_index = df.iloc[top_docs].sentencia.unique()

# %%
cache_df = df[df.sentencia.isin(top_p_index)].copy()

# %%
top_df = df.iloc[top_docs].copy()
top_df
# Out:
#          Unnamed: 0  p_index tag                                      text  \
# 4144134     4144134     3318   p                “Sobre la consulta previa.
# 4143879     4143879     2814   p                “Sobre la consulta previa.
# 5554760     5554760     1610   p                       a.  Consulta previa
# 3175467     3175467      397   p                           CONSULTA PREVIA
# 3175648     3175648      744   p                     Consulta\r\n  previa
# 5215288     5215288     3297   p                    La\r\nconsulta previa
# 1904403     1904403      549   p                      Consulta\r\n  previa
# 1904739     1904739     1085   p                      Consulta\r\n  previa
# 1396507     1396507      354   p                           Consulta Previa
# 829883       829883      130   p                      Consulta\r\n  previa
# 4052350     4052350      360   p                           Consulta previa
# 4352239     4352239      401   p                           Consulta previa
# 991092       991092      282  h2                           Consulta previa
# 1414085     1414085      283   p                      Consulta\r\n  previa
# 2077438     2077438      184   p                      Consulta\r\n  previa
# 6227442     6227442      269   p  La procedencia\r\nde la consulta previa
# 4145052     4145052     4950   p           Inexistencia de consulta previa
# 991099       991099      291   p         -Procedimiento de consulta previa
# 437029       437029       22   p          CONSULTA PREVIA-Características
# 1706656     1706656       26   p          CONSULTA PREVIA-Características
# 6126556     6126556       47   p               CONSULTA PREVIA-Titularidad
# 1324881     1324881       39   p               CONSULTA PREVIA-Fundamental
#
#                                    class_  sentencia  \
# 4144134                         MsoNormal   T-733-17
# 4143879                         MsoNormal   T-733-17
# 5554760                  MsoListParagraph   T-236-17
# 3175467                         MsoNormal   SU123-18
# 3175648                         MsoNormal   SU123-18
# 5215288                         MsoNormal   C-154-16
# 1904403                      MsoNoSpacing   C-020-18
# 1904739                      MsoNoSpacing   C-020-18
# 1396507                         MsoNormal   C-098-20
# 829883   Cuadrculaclara-nfasis31CxSpFirst   C-494-19
# 4052350        MsoListParagraphCxSpMiddle   SU111-20
# 4352239                         MsoNormal   C-025-18
# 991092                           no_class   T-576-14
# 1414085     MediumGrid1-Accent21CxSpFirst   C-252-19
# 2077438     MediumGrid1-Accent21CxSpFirst   C-491-19
# 6227442                       MsoBodyText   T-247-15
# 4145052                         MsoNormal   T-733-17
# 991099                          MsoNormal   T-576-14
# 437029                          MsoNormal   T-011-18
# 1706656                         MsoNormal   T-568-17
# 6126556                         MsoNormal  C-1051-12
# 1324881                         MsoNormal   T-348-12
#
#                                  link                                    pp  \
# 4144134   Relatoria/2017/T-733-17.htm              sobre la consulta previa
# 4143879   Relatoria/2017/T-733-17.htm              sobre la consulta previa
# 5554760   Relatoria/2017/T-236-17.htm                   a\n consulta previa
# 3175467   Relatoria/2018/SU123-18.htm                       consulta previa
# 3175648   Relatoria/2018/SU123-18.htm                       consulta previa
# 5215288   Relatoria/2016/C-154-16.htm                    la consulta previa
# 1904403   Relatoria/2018/C-020-18.htm                       consulta previa
# 1904739   Relatoria/2018/C-020-18.htm                       consulta previa
# 1396507   Relatoria/2020/C-098-20.htm                       consulta previa
# 829883    Relatoria/2019/C-494-19.htm                       consulta previa
# 4052350   Relatoria/2020/SU111-20.htm                       consulta previa
# 4352239   Relatoria/2018/C-025-18.htm                       consulta previa
# 991092    Relatoria/2014/T-576-14.htm                       consulta previa
# 1414085   Relatoria/2019/C-252-19.htm                       consulta previa
# 2077438   Relatoria/2019/C-491-19.htm                       consulta previa
# 6227442   Relatoria/2015/T-247-15.htm  la procedencia de la consulta previa
# 4145052   Relatoria/2017/T-733-17.htm       inexistencia de consulta previa
# 991099    Relatoria/2014/T-576-14.htm      procedimiento de consulta previa
# 437029    Relatoria/2018/T-011-18.htm       consulta previa características
# 1706656   Relatoria/2017/T-568-17.htm       consulta previa características
# 6126556  Relatoria/2012/C-1051-12.htm           consulta previa titularidad
# 1324881   Relatoria/2012/T-348-12.htm           consulta previa fundamental
#
#                              pp_sin_stop  \
# 4144134                  consulta previa
# 4143879                  consulta previa
# 5554760                  consulta previa
# 3175467                  consulta previa
# 3175648                  consulta previa
# 5215288                  consulta previa
# 1904403                  consulta previa
# 1904739                  consulta previa
# 1396507                  consulta previa
# 829883                   consulta previa
# 4052350                  consulta previa
# 4352239                  consulta previa
# 991092                   consulta previa
# 1414085                  consulta previa
# 2077438                  consulta previa
# 6227442      procedencia consulta previa
# 4145052     inexistencia consulta previa
# 991099     procedimiento consulta previa
# 437029   consulta previa características
# 1706656  consulta previa características
# 6126556      consulta previa titularidad
# 1324881      consulta previa fundamental
#
#                                                        vec  is_vec
# 4144134  [0.00029730183, -0.00046576452, 0.0011197131, ...    True
# 4143879  [0.00029730183, -0.00046576452, 0.0011197131, ...    True
# 5554760  [0.00029730183, -0.00046576452, 0.0011197131, ...    True
# 3175467  [0.00029730183, -0.00046576452, 0.0011197131, ...    True
# 3175648  [0.00029730183, -0.00046576452, 0.0011197131, ...    True
# 5215288  [0.00029730183, -0.00046576452, 0.0011197131, ...    True
# 1904403  [0.00029730183, -0.00046576452, 0.0011197131, ...    True
# 1904739  [0.00029730183, -0.00046576452, 0.0011197131, ...    True
# 1396507  [0.00029730183, -0.00046576452, 0.0011197131, ...    True
# 829883   [0.00029730183, -0.00046576452, 0.0011197131, ...    True
# 4052350  [0.00029730183, -0.00046576452, 0.0011197131, ...    True
# 4352239  [0.00029730183, -0.00046576452, 0.0011197131, ...    True
# 991092   [0.00029730183, -0.00046576452, 0.0011197131, ...    True
# 1414085  [0.00029730183, -0.00046576452, 0.0011197131, ...    True
# 2077438  [0.00029730183, -0.00046576452, 0.0011197131, ...    True
# 6227442  [-0.0003572864, -0.0004952931, 0.0010996367, 0...    True
# 4145052  [-3.1277945e-05, -0.000121261226, 0.0008867448...    True
# 991099   [-0.00035201214, -0.00078961457, 0.0012154587,...    True
# 437029   [-1.7748234e-05, -0.00035556316, 0.00081804505...    True
# 1706656  [-1.7748234e-05, -0.00035556316, 0.00081804505...    True
# 6126556  [-0.00025587957, -0.0007350263, 0.00073664985,...    True
# 1324881  [0.00023586205, -0.00015231392, 0.00056903786,...    True

# %%
def get_paragraphs(dataframe, document, paragraph, window):
    doc_p_list = np.sort(dataframe[dataframe["sentencia"]==document]["p_index"].values)
    paragraph_i = np.where(doc_p_list == paragraph)[0][0]
    p_indices = doc_p_list[paragraph_i-window//2 : paragraph_i+window//2 + 1]
    range_from, range_to = min(p_indices), max(p_indices)
    paragraphs = df.query(f'sentencia==@document & p_index>=@range_from & p_index<=@range_to')["text"]
    paragraphs = [re.sub("\s+", " ", p) for p in paragraphs]
    return '\n'.join(paragraphs)

# %%
print(get_paragraphs(df, "T-733-17", 3318, 3))
# Out:
# Así mismo, agrega el ente fiscal que:
# “Sobre la consulta previa.
# “En la zona de influencia del proyecto existen comunidades negras e indígenas que han participado en procesos de consulta previa por parte de la empresa Cerro Matoso S. A., pero de manera esporádica, dispersa e incompleta. Hoy, con unas condiciones distintas que implican situaciones contractuales nuevas y de hecho procesos industriales diferentes, así como impactos sociales ambientales distintos a aquellos que se preveían anteriormente, ante la formalización del denominado otrosí N° 4 se hubiera requerido realizar un nuevo proceso de consulta previa por cuanto se trata de una decisión que afecta a dichas comunidades. Esta situación está contemplada en el Convenio 169 de la OIT, ratificado por Colombia por la Ley 21 de 1991. Por tratarse de un convenio internacional sobre derechos humanos, hace parte del bloque de constitucionalidad del país, por lo cual prevalece sobre otras disposiciones internas”[216].

# %%
P_WINDOW_SIZE = 3

# %%
top_df["distance"] = top_dist
top_df.drop_duplicates(subset="sentencia", keep="first", inplace=True, ignore_index=True)

# %%
for i, doc in enumerate(zip(top_df.sentencia, top_df.p_index, top_df.distance)):
    print(f"{i+1}. {doc[0]} - párrafo {doc[1]} (Similaridad {1-doc[2]: .1%}):\n")
    print(get_paragraphs(cache_df, doc[0], doc[1], P_WINDOW_SIZE))
    print("-"*50)

# for i, doc in enumerate(zip(df.iloc[top_docs].text, df.iloc[top_docs].sentencia, df.iloc[top_docs].p_index, top_dist)):
#     print(f"{i+1}. {doc[1]} - párrafo {doc[2]} (Similaridad {doc[3]:.4f}):\n{doc[0][:CARACTERES]}")
#     print("-"*50)
# Out:
# 1. T-733-17 - párrafo 3318 (Similaridad  100.0%):
#
# Así mismo, agrega el ente fiscal que:
# “Sobre la consulta previa.
# “En la zona de influencia del proyecto existen comunidades negras e indígenas que han participado en procesos de consulta previa por parte de la empresa Cerro Matoso S. A., pero de manera esporádica, dispersa e incompleta. Hoy, con unas condiciones distintas que implican situaciones contractuales nuevas y de hecho procesos industriales diferentes, así como impactos sociales ambientales distintos a aquellos que se preveían anteriormente, ante la formalización del denominado otrosí N° 4 se hubiera requerido realizar un nuevo proceso de consulta previa por cuanto se trata de una decisión que afecta a dichas comunidades. Esta situación está contemplada en el Convenio 169 de la OIT, ratificado por Colombia por la Ley 21 de 1991. Por tratarse de un convenio internacional sobre derechos humanos, hace parte del bloque de constitucionalidad del país, por lo cual prevalece sobre otras disposiciones internas”[216].
# --------------------------------------------------
# 2. T-236-17 - párrafo 1610 (Similaridad  100.0%):
#
# La profesora Gloria Amparo Rodríguez envió a la Corte dos documentos: un concepto dado por la Especialización en Derecho Ambiental, relacionado con el problema jurídico de la consulta previa, y un concepto dado por la Dirección de la Especialización y la Línea de Investigación en Derecho Ambiental en relación con el principio de precaución. Este último concepto también fue suscrito por el profesor Andrés Gómez Rey, de la misma universidad.
# a. Consulta previa
# La profesora Rodríguez sostiene que la consulta previa es un derecho fundamental que tienen las comunidades étnicas para participar en la toma de decisiones que les afectan directamente y decidir sus propias prioridades en los procesos de desarrollo. Reseña los principales fundamentos jurídicos del derecho a la consulta previa y señala los criterios mínimos que, a su juicio, deben guiar una consulta adecuada, entre los cuales se encuentran la buena fe, la consulta informada y la consulta culturalmente adecuada. Resalta adicionalmente que la consulta debe ser previa y que se deben consultar todas las medidas susceptibles de afectar directamente a las comunidades étnicas.
# --------------------------------------------------
# 3. SU123-18 - párrafo 397 (Similaridad  100.0%):
#
# 11.5. El siguiente cuadro señala las distinciones fundamentales entre el derecho a la consulta previa y el derecho al consentimiento libre e informado.
# CONSULTA PREVIA
# CONSENTIMIENTO PREVIO LIBRE E INFORMADO
# --------------------------------------------------
# 4. C-154-16 - párrafo 3297 (Similaridad  100.0%):
#
# Bajo estos parámetros, la Sala encuentra cumplidos estos requisitos por el proyecto estatutario que se revisa, no solo por cuanto la iniciativa surtió en cada célula legislativa la discusión y aprobación respectiva, sino que pese a la enmienda presentada en la ponencia para segundo debate en la Plenaria de la Cámara de Representantes, el proyecto conservó su identidad en tanto que la discusión giró siempre sobre los beneficios y consecuencias de implementar o no las Salas de Descongestión Laboral de la Corte Suprema de Justicia.
# La consulta previa
# 32.- Conforme a la jurisprudencia constitucional es obligatoria la realización de consulta previa a las comunidades étnicas cuando el contenido de la iniciativa legislativa consagre medidas que puedan impactarlas directamente.[45]
# --------------------------------------------------
# 5. C-020-18 - párrafo 549 (Similaridad  100.0%):
#
# 15
# Consulta previa
# E. Análisis del Acto Legislativo 4 de 8 de septiembre de 2017 en relación con los requisitos antes referidos
# --------------------------------------------------
# 6. C-098-20 - párrafo 354 (Similaridad  100.0%):
#
# Por lo anterior, se concluye que la adopción del instrumento internacional en mención cumplió con el requisito de forma relacionado con la calidad de la persona que debía suscribir el acuerdo internacional.
# Consulta Previa
# 19. Para la Sala Plena de la Corte Constitucional, el "Acuerdo entre la República de Colombia y la Organización para la Cooperación y Desarrollo Económico (OCDE) sobre privilegios, inmunidades y facilidades otorgados a la Organización", suscrito en Punta Mita, México, el 20 de junio de 2014 y su ley aprobatoria, no exigía de manera obligatoria adelantar el proceso de consulta previa, pues los objetivos, contenido y alcance del convenio internacional no suponen una afectación directa a la vida y/o costumbres de las comunidades étnicas del país. Se recuerda, (i) que el objeto y fin del convenio internacional se circunscribe a establecer un marco general en materia de privilegios e inmunidades para la OCDE y sus miembros, en caso de operar en Colombia, y (ii) ninguna de sus cláusulas se refiere o tiene que ver con los pueblos indígenas o comunidades étnicas, o a sus costumbres tradicionales.
# --------------------------------------------------
# 7. C-494-19 - párrafo 130 (Similaridad  100.0%):
#
# Cumple
# Consulta previa
# Aprobación presidencial y sometimiento del tratado a consideración del Congreso
# --------------------------------------------------
# 8. SU111-20 - párrafo 360 (Similaridad  100.0%):
#
# En relación con la legitimidad del convenio suscrito con AGROMAR, el CINEP estima que la remisión al Reglamento Interno puede ser engañosa, “pues algunas personas que pertenecen al Consejo Comunitario aseguran que existen dos versiones de reglamentos internos: i) una versión que se acoge a los lineamientos de la Ley 70 de 1993 y el Decreto 1745 de 1995 […] y ii) una versión de reglamentos que presuntamente fue elaborada por asesores jurídicos de terceros ajenos al territorio (empresarios) que usufructúan la tierra, y que se encuentra en contravía de algunos pilares fundamentales de la legislación étnica y constitucional”[108]. En esta última versión, por ejemplo, “se genera un conjunto de posibilidades y estrategias para que el Consejo Comunitario consiga generar contratos, acuerdos o usufructos con personas naturales o jurídicas nacionales o extranjeras”[109].
# Consulta previa
# Demandantes
# --------------------------------------------------
# 9. C-025-18 - párrafo 401 (Similaridad  100.0%):
#
# La Sala quiere dejar claro, finalmente en este acápite, que el Decreto Ley en análisis, es eminentemente procedimental, en tanto las líneas gruesas sobre las amnistías e indultos, han quedado trazadas –en específico- en la Ley 1820 de 2016. Por ello se enfatiza en el hecho de que la reiteración casi literal que en muchos casos efectúa el Decreto Ley 277 de 2017, ha de entenderse por la necesidad de contextualizar la respectiva regla de trámite, pues de lo contrario se correría el riesgo de generar dudas y perplejidades que dificultarían, con mucho, la cabal y correcta aplicación de las normas sustantivas.
# Consulta previa
# 51. La jurisprudencia constitucional reconoce la consulta previa como un derecho fundamental de las comunidades indígenas, tribales, afro-descendientes, raizales y del pueblo Rrom, a partir de lo dispuesto en el Convenio 169 de la Organización Internacional del Trabajo, el cual integra el bloque de constitucionalidad en sentido estricto[12]. De acuerdo a lo establecido en el artículo 6.1 (a) del citado Convenio[13], la Corte ha señalado que la consulta previa es obligatoria, siempre que se demuestre una “afectación directa” a los sujetos titulares de este derecho, es decir, a las comunidades indígenas, tribales, afro-descendientes, raizales y al pueblo Rrom[14].
# --------------------------------------------------
# 10. T-576-14 - párrafo 282 (Similaridad  100.0%):
#
# En el Congreso de Quibdó hubo un sector minoritario de consejos comunitarios que decidió apartarse del consenso citado. No obstante, el viceministro para la participación e igualdad de derechos sostuvo una reunión formal con sus líderes y representantes, para atender sus preocupaciones y avanzar en su inclusión en la mesa transitoria de interlocución.
# Consulta previa
# La mesa que se encargó de este tema deliberó en torno a un protocolo de consulta previa que quedó consignado en los documentos de consenso mayoritario del Congreso. La propuesta de protocolo contempla los siguientes puntos:
# --------------------------------------------------
# 11. C-252-19 - párrafo 283 (Similaridad  100.0%):
#
# Cumple
# Consulta previa
# Aprobación presidencial y sometimiento del tratado a consideración del Congreso
# --------------------------------------------------
# 12. C-491-19 - párrafo 184 (Similaridad  100.0%):
#
# Cumple
# Consulta previa
# Aprobación presidencial y sometimiento del tratado a consideración del Congreso
# --------------------------------------------------
# 13. T-247-15 - párrafo 269 (Similaridad  91.6%):
#
# 44. Visto el anterior panorama, entrará la Sala a determinar si, para llevar a cabo los procedimientos de Actualización y Formación catastral ordenados mediante Resolución Número 50-000-044-2012 del 23 de mayo de 2012, dados sus alcances, y la presencia de varias comunidades indígenas, era necesaria la realización del procedimiento de Consulta Previa con el fin de resguardar los derechos fundamentales de estas comunidades.
# La procedencia de la consulta previa
# Para determinar la procedencia de la Consulta Previa en este caso, esta Sala entrará a realizar una caracterización general de la misma y por último su procedencia en relación con las actuaciones administrativas de Actualización y Formación catastral en el caso concreto.
# --------------------------------------------------
# 14. T-011-18 - párrafo 22 (Similaridad  91.3%):
#
# En la sentencia T-766 de 2015, reiterando jurisprudencia, se indicó que: “la afectación directa a las comunidades indígenas y afrodescendientes por parte de una medida legislativa o administrativa puede verificarse en tres escenarios: (i) cuando la medida tiene por objeto regular un tópico que, por expresa disposición constitucional, debe ser sometido a procesos de decisión que cuenten con la participación de las comunidades étnicas, como sucede con la explotación de recursos naturales; (ii) cuando a pesar de que no se trate de esas materias, el asunto regulado por la medida está vinculado con elementos que conforman la identidad particular de las comunidades diferenciadas; y (iii) cuando, aunque se está ante una medida de carácter general, regula sistemáticamente materias que conforman la identidad de las comunidades tradicionales, por lo que puede generarse o bien una posible afectación, un déficit de protección de los derechos de las comunidades o una omisión legislativa relativa que las discrimine”.
# CONSULTA PREVIA-Características
# Entre otras, (i) debe ser adelantada por personas que representen realmente a la comunidad; (ii) debe estar antecedida de un proceso preconsultivo, en el cual es posible delimitar la forma como llevará acabo; (iii) debe ser realizada con antelación a la medida que pueda afectar directamente a la comunidad; (vi) debe tener la capacidad de generar efectos en la decisión y (v) debe partir de un enfoque diferencial, en el que se valoren los rasgos culturales que identifican a cada pueblo. Por último, si bien en algunos casos excepcionales se requiere el consentimiento informado de las comunidades, la atribución para decidir finalmente sobre el desarrollo una política estatal reside exclusivamente en las autoridades públicas, sin que por ello se entiendan autorizadas para incurrir en actos arbitrarios respecto de las resoluciones que adopten.
# --------------------------------------------------
# 15. T-568-17 - párrafo 26 (Similaridad  91.3%):
#
# En la sentencia T-766 de 2015, reiterando jurisprudencia, se indicó que: “la afectación directa a las comunidades indígenas y afrodescendientes por parte de una medida legislativa o administrativa puede verificarse en tres escenarios: (i) cuando la medida tiene por objeto regular un tópico que, por expresa disposición constitucional, debe ser sometido a procesos de decisión que cuenten con la participación de las comunidades étnicas, como sucede con la explotación de recursos naturales;(ii) cuando a pesar de que no se trate de esas materias, el asunto regulado por la medida está vinculado con elementos que conforman la identidad particular de las comunidades diferenciadas; y (iii) cuando, aunque se está ante una medida de carácter general, regula sistemáticamente materias que conforman la identidad de las comunidades tradicionales, por lo que puede generarse o bien una posible afectación, un déficit de protección de los derechos de las comunidades o una omisión legislativa relativa que las discrimine”.
# CONSULTA PREVIA-Características
# Entre otras, (i) debe ser adelantada por personas que representen realmente a la comunidad; (ii) debe estar antecedida de un proceso preconsultivo, en el cual es posible delimitar la forma como llevará acabo; (iii) debe ser realizada con antelación a la medida que pueda afectar directamente a la comunidad; (vi) debe tener la capacidad de generar efectos en la decisión y (v) debe partir de un enfoque diferencial, en el que se valoren los rasgos culturales que identifican a cada pueblo. Por último, si bien en algunos casos excepcionales se requiere el consentimiento informado de las comunidades, la atribución para decidir finalmente sobre el desarrollo una política estatal reside exclusivamente en las autoridades públicas, sin que por ello se entiendan autorizadas para incurrir en actos arbitrarios respecto de las resoluciones que adopten.
# --------------------------------------------------
# 16. C-1051-12 - párrafo 47 (Similaridad  91.1%):
#
# CONSULTA PREVIA DE LAS COMUNIDADES ETNICAS-Reglas jurisprudenciales para determinar la necesidad de dicha consulta
# CONSULTA PREVIA-Titularidad
# La Corte ha explicado que el derecho a la consulta previa se extiende en favor de los diferentes grupos étnicos, cualquiera sea su origen y condición, entendiendo que el concepto comprende, para el caso colombiano, a las comunidades y pueblos indígenas y tribales, negros o afro-descendientes y raizales.
# --------------------------------------------------
# 17. T-348-12 - párrafo 39 (Similaridad  90.6%):
#
# CONSULTA PREVIA-Mecanismo de participación en la toma de decisiones ambientales
# CONSULTA PREVIA-Fundamental
# CONSULTA PREVIA EN MATERIA AMBIENTAL-Consulta a comunidades indígenas y afrodescendientes antes de expedir licencia ambiental para proyecto de exploración o explotación de recursos naturales
# --------------------------------------------------

# %%
tmp_df = df
tmp_df["distances"] = distances

# %%
sentencia_obj = 'SU039-97'
min_distance = np.min(tmp_df[tmp_df.sentencia==sentencia_obj].distances)

print("Mínima distancia de la sentencia {1}: {0:.4f}".format(min_distance, sentencia_obj))
# Out:
# Mínima distancia de la sentencia SU039-97: 0.5840

# %%
print(tmp_df[(tmp_df.sentencia==sentencia_obj)&(tmp_df.distances==min_distance)].text.values[0])
# Out:
# 5.      Tampoco tuvo
# en cuenta la sentencia mencionada conforme se establece claramente en la
# sentencia de la Corte Suprema de Justicia y en la providencia del Consejo de
# Estado que negó la suspensión provisional de la Resolución acusada, si
# existieron las reuniones previas para que se hiciera efectiva la consulta
# alegada, lo que impide la viabilidad del mecanismo transitorio y del perjuicio
# irremediable invocado por los demandantes.

# %%
for i, r in tmp_df[(tmp_df.sentencia==sentencia_obj)&(tmp_df.text.str.contains("consulta previa"))].iterrows():
    print(r.pp)
    print("-"*50)
# Out:
# no obstante dicha dependencia llamó la atención en términos de la participación comunitaria y ciudadana y en lo que tiene que ver particularmente con la etnia u wa asentada en el área de influencia puntual y local del proyecto de conformidad con lo establecido en el artículo <num> de la constitución como en la ley <num> de <num> en su artículo <num> específicamente en lo que hace referencia a la consulta previa así como en la legislación indígena nacional vigente
# --------------------------------------------------
# <num>
# <num>
#  el ministerio del medio ambiente como consulta previa para los efectos de la expedición de la licencia ambiental tuvo como tal la reunión que sostuvieron algunos miembros de la comunidad u wa los días <num> y <num> de enero de <num> en la ciudad de arauca con participación de representantes de los ministerios de minas y energía y del medio ambiente ecopetrol y la occidental de colombia inc
#  y en tal virtud procedió a expedir la resolución no
#  <num> de febrero <num> de <num> mediante la cual se otorgó dicha licencia
# --------------------------------------------------
# b se ordene a la parte demandada ministerio del medio ambiente y sociedad occidental de colombia inc
#  iniciar desarrollar y ejecutar todas las diligencias actividades y procedimientos necesarios para llevar a cabo el proceso de consulta previa con la comunidad u wa
# --------------------------------------------------
# <num>
# <num>
#  en la demanda de nulidad se solicitó la suspensión provisional del acto acusado invocando la violación manifiesta de los arts
#  <num> <num> <num> parágrafo de la constitución <num> de la ley <num> <num> y <num> y <num> del convenio <num> de la o
# i
# t
#  el concepto de su violación se hace consistir en el desconocimiento de la participación ciudadana y comunitaria en este tipo de proyectos al no haberse cumplido con el requisito de la consulta previa a la comunidad u wa
# --------------------------------------------------
# en concepto de dicha parte la consulta previa a la expedición de la licencia ambiental no se realizó pues como consulta previa no pueden ser tenidas en cuenta las reuniones que se realizaron en el municipio de arauca los días <num> y <num> de enero de <num>
# --------------------------------------------------
# que según la comunidad u wa y la referida dirección la consulta previa exigida por la constitución y las normas nacionales e internacionales se inició pero no se agotó con la reunión del <num> y <num> de enero de <num> y que su voluntad desde un principio y actualmente ha sido la de oponerse a la ejecución del proyecto de prospección sísmica debido a los riesgos que éste entraña para su supervivencia como grupo étnico por los bruscos cambios en su entorno físico y en sus condiciones culturales económicas y cosmogónicas
# --------------------------------------------------
# pone de presente la corte la posición contradictoria de las autoridades del ministerio del interior y del ministerio del medio ambiente pues mientras las primeras aseveran que la consulta no existió las segundas afirman lo contrario
#  obviamente la corte analizada la abundante prueba incorporada a los autos se inclina por la posición de que no existió dicha consulta previa
# --------------------------------------------------

# %%
# for i, doc in enumerate(zip(df.iloc[top_docs].text, df.iloc[top_docs].sentencia, df.iloc[top_docs].p_index, top_dist)):
#     print(f"{i+1}. {doc[1]} - párrafo {doc[2]} (Similaridad {doc[3]:.4f}):\n{doc[0][:CARACTERES]}")
#     print("-"*50)

# %% [markdown]
# ## **Búsqueda Literal**

# %%
busqueda = "ponente alejandro linares cantillo"

# %%
df["año"] = [x.split()[0].split("-")[-1] for x in df.INDEX.values]

# %%
AÑO_INICIO = 11
AÑO_FIN = 19
TIPO_SENTENCIA = 'S'

# %%
print("Total encontrados:", len(df[(df.pp.str.contains(busqueda.lower()))&(df.tipo==TI)&]))
print("-"*20)
df_tmp = df[(df.pp.str.contains(busqueda.lower()))&(df.tipo=='S')].head(N_TOP_DOCS)

for i, doc in enumerate(zip(df_tmp.DOCUMENT, df_tmp.INDEX)):
    print(f"{i+1}. {doc[1]}:\n{doc[0][:CARACTERES]}")
    print("-"*70)
# Out:
# Total encontrados: 5
# --------------------
# 1.  SU495-20:
# sentencia su49520
#
#
# referencia:
# expediente t-7.783.646
#
# acción de
# tutela interpuesta por dorian jaime mejía galeano contra la
# sala de definición de situaciones jurídicas y la sección de apelación del
# tribunal para la paz de la jurisdicción especial para la paz.
#
# magistrado
# ponente:
# alejandro
# linares cantillo
#
#
# bogotá, d.c., veintisiete (27) de noviembre de dos mil
# veinte (2020)
#
#
# la sala plena de la corte constitucional, en ejercicio de
# sus atribuciones constitucionales y de los
# ----------------------------------------------------------------------
# 2.  SU379-19:
# nota de
# relatoria: mediante auto
# 586 de fecha 29 de octubre de 2019, el cual se anexa a la presente providencia,
# se aclara la orden proferida en el resolutivo tercero, en el sentido de indicar
# que se deja sin efectos únicamente la decisión proferida dentro del proceso de pérdida
# de investidura contra el señor álvaro escobar gonzález, en segunda instancia,
# por la sección primera del consejo de estado el 2 de junio de 2016, dejando
# inalterados los demás contenidos de la misma.
#
#
# sentenci
# ----------------------------------------------------------------------
# 3.  SU062-18:
# sentencia su06218
#
# accion de tutela contra
# providencias judiciales-requisitos generales y especiales de procedibilidad
#
# defecto procedimental por
# exceso ritual manifiesto y defecto factico por omision en la valoracion de las
# pruebas
#
# defecto factico-dimensión
# negativa por no incorporar, practicar o valorar pruebas solicitadas o
# decretadas
#
# la sala concluye que la omisión de incorporar y, en
# consecuencia, de valorar una prueba solicitada o insinuada en el proceso y
# requerida para estab
# ----------------------------------------------------------------------
# 4.  SU588-16:
# sentencia su58816
#
#
# accion de tutela
# para ordenar reconocimiento y pago de la pension de invalidez-procedencia excepcional
#
# accion
# de tutela para el reconocimiento de pension de invalidez-reglas de
# procedencia
#
# personas con
# discapacidad como sujetos de especial proteccion constitucional-protección nacional e internacional
#
# el estado colombiano
# debe, a través de todos sus estamentos, garantizar a todas las personas el
# efectivo goce de sus derechos constitucionales. en desarrollo de d
# ----------------------------------------------------------------------
# 5.  SU391-16:
# sentencia su39116
#
#
# cosa juzgada
# constitucional-configuración
#
# en primer lugar, existe identidad de partes entre
# la acción de tutela promovida en enero de 2013 y la presentada en esta ocasión.
# en segundo lugar, existe identidad de hechos, por cuanto el sustento fáctico
# para formular la vulneración del derecho a la igualdad es el mismo en la acción
# de tutela planteada en enero de 2013 y en la que revisa la corte en esta
# ocasión. así, en ambos casos la supuesta vulneración se basa en la
#
# ----------------------------------------------------------------------

# %%
def get_ponente(text):
    if "magistrado ponente" not in text:
        return "N/A"
    indice = text.index("ponente")
    ponente = " ".join(text[indice:indice+200].split()[1:4])
    return ponente

# %%
df[df.tipo!='A'].head()
# Out:
#           INDEX DOCUMENT_TYPE  \
# 8739   T-020-21             T
# 8740   T-019-21             T
# 8741   T-017-21             T
# 8742   T-015-21             T
# 8743   T-002-21             T
#
#                                                    LINK  \
# 8739  https://www.corteconstitucional.gov.co/Relator...
# 8740  https://www.corteconstitucional.gov.co/Relator...
# 8741  https://www.corteconstitucional.gov.co/Relator...
# 8742  https://www.corteconstitucional.gov.co/Relator...
# 8743  https://www.corteconstitucional.gov.co/Relator...
#
#                                                DOCUMENT  \
# 8739  sentencia t-02021\n \n \nreferencia: expedient...
# 8740  sentencia t-01921\n \n \nreferencia:\r\nexpedi...
# 8741  sentencia\r\nt-01721\n \n \nreferencia: expedi...
# 8742  sentencia t-01521\n \n \nreferencia: expedient...
# 8743  sentencia t-00221\n \n \nreferencia: expedient...
#
#                                     DOCUMENT_WITH_SIGNS  \
# 8739  sentencia t-02021  referencia: expedientes (i)...
# 8740  sentencia t-01921  referencia: expediente t-7....
# 8741  sentencia t-01721  referencia: expediente t-7....
# 8742  sentencia t-01521  referencia: expediente t-7....
# 8743  sentencia t-00221  referencia: expediente t-7....
#
#                                          DOCUMENT_CLEAN tipo  \
# 8739  sentencia t 02021 referencia expedientes i t 7...    T
# 8740  sentencia t 01921 referencia expediente t 7 89...    T
# 8741  sentencia t 01721 referencia expediente t 7 91...    T
# 8742  sentencia t 01521 referencia expediente t 7 89...    T
# 8743  sentencia t 00221 referencia expediente t 7 87...    T
#
#                                                      pp  \
# 8739  sentencia t 02021 referencia expedientes i t 7...
# 8740  sentencia t 01921 referencia expediente t 7 89...
# 8741  sentencia t 01721 referencia expediente t 7 91...
# 8742  sentencia t 01521 referencia expediente t 7 89...
# 8743  sentencia t 00221 referencia expediente t 7 87...
#
#                                                     vec  is_vec año  \
# 8739  [-8.243717e-05, 3.299988e-05, -5.2083982e-05, ...    True  21
# 8740  [-3.213584e-05, 6.351033e-05, -9.341354e-05, -...    True  21
# 8741  [-0.00026038743, 4.8819413e-05, -7.825945e-05,...    True  21
# 8742  [-4.1070634e-05, -9.840238e-05, -0.00013082263...    True  21
# 8743  [-0.00014265596, -1.723251e-05, -0.00015529948...    True  21
#
#                          ponente
# 8739                         N/A
# 8740                    el 14 de
# 8741  cristina pardo schlesinger
# 8742        diana fajardo rivera
# 8743              de la libertad

# %%
df.tipo.value_counts()
# Out:
# T    18786
# A     8737
# C     6529
# S      388
# Name: tipo, dtype: int64

# %%
df["ponente"] = [get_ponente(text) if tipo!='A' else "N/A" for text, tipo in zip(df.pp.values, df.tipo.values)]

# %%
df[df.tipo!='A'].head()
# Out:
#           INDEX DOCUMENT_TYPE  \
# 8739   T-020-21             T
# 8740   T-019-21             T
# 8741   T-017-21             T
# 8742   T-015-21             T
# 8743   T-002-21             T
#
#                                                    LINK  \
# 8739  https://www.corteconstitucional.gov.co/Relator...
# 8740  https://www.corteconstitucional.gov.co/Relator...
# 8741  https://www.corteconstitucional.gov.co/Relator...
# 8742  https://www.corteconstitucional.gov.co/Relator...
# 8743  https://www.corteconstitucional.gov.co/Relator...
#
#                                                DOCUMENT  \
# 8739  sentencia t-02021\n \n \nreferencia: expedient...
# 8740  sentencia t-01921\n \n \nreferencia:\r\nexpedi...
# 8741  sentencia\r\nt-01721\n \n \nreferencia: expedi...
# 8742  sentencia t-01521\n \n \nreferencia: expedient...
# 8743  sentencia t-00221\n \n \nreferencia: expedient...
#
#                                     DOCUMENT_WITH_SIGNS  \
# 8739  sentencia t-02021  referencia: expedientes (i)...
# 8740  sentencia t-01921  referencia: expediente t-7....
# 8741  sentencia t-01721  referencia: expediente t-7....
# 8742  sentencia t-01521  referencia: expediente t-7....
# 8743  sentencia t-00221  referencia: expediente t-7....
#
#                                          DOCUMENT_CLEAN tipo  \
# 8739  sentencia t 02021 referencia expedientes i t 7...    T
# 8740  sentencia t 01921 referencia expediente t 7 89...    T
# 8741  sentencia t 01721 referencia expediente t 7 91...    T
# 8742  sentencia t 01521 referencia expediente t 7 89...    T
# 8743  sentencia t 00221 referencia expediente t 7 87...    T
#
#                                                      pp  \
# 8739  sentencia t 02021 referencia expedientes i t 7...
# 8740  sentencia t 01921 referencia expediente t 7 89...
# 8741  sentencia t 01721 referencia expediente t 7 91...
# 8742  sentencia t 01521 referencia expediente t 7 89...
# 8743  sentencia t 00221 referencia expediente t 7 87...
#
#                                                     vec  is_vec año   ponente
# 8739  [-8.243717e-05, 3.299988e-05, -5.2083982e-05, ...    True  21       N/A
# 8740  [-3.213584e-05, 6.351033e-05, -9.341354e-05, -...    True  21  el 14 de
# 8741  [-0.00026038743, 4.8819413e-05, -7.825945e-05,...    True  21       N/A
# 8742  [-4.1070634e-05, -9.840238e-05, -0.00013082263...    True  21       N/A
# 8743  [-0.00014265596, -1.723251e-05, -0.00015529948...    True  21       N/A

# %%
ponentes = df.ponente.value_counts().to_frame()

# %%
ponentes[(ponentes.ponente>5)]
# Out:
#                        ponente
# N/A                      12120
# dr alvaro tafur            998
# dr marco gerardo           975
# dr alfredo beltrán         964
# dr rodrigo escobar         921
# ...                        ...
# dr ciro angarita             6
# fabio morón díaz             6
# jaime araújo rentería        6
# josé antonio cepeda          6
# e dr jairo                   6
#
# [112 rows x 1 columns]

# %%
for i, (index, r) in enumerate(ponentes.iterrows()):
    print(i, index, r.ponente)
# Out:
# 0 N/A 12120
# 1 dr alvaro tafur 998
# 2 dr marco gerardo 975
# 3 dr alfredo beltrán 964
# 4 dr rodrigo escobar 921
# 5 dr jaime córdoba 891
# 6 dr manuel josé 740
# 7 dr humberto antonio 705
# 8 mauricio gonzález cuervo 680
# 9 dr carlos gaviria 633
# 10 dr jaime araújo 616
# 11 dr jose gregorio 587
# 12 jorge ignacio pretelt 572
# 13 gabriel eduardo mendoza 566
# 14 luis guillermo guerrero 565
# 15 dr eduardo cifuentes 544
# 16 dr fabio moron 542
# 17 luis ernesto vargas 502
# 18 dr vladimiro naranjo 502
# 19 jorge iván palacio 470
# 20 dr nilson pinilla 469
# 21 dr antonio barrera 436
# 22 dr hernando herrera 421
# 23 alberto rojas ríos 415
# 24 dr alejandro martínez 378
# 25 dr jaime araujo 361
# 26 dr eduardo montealegre 355
# 27 dr josé gregorio 348
# 28 dr alejandro martinez 335
# 29 nilson pinilla pinilla 316
# 30 alejandro linares cantillo 290
# 31 dr jorge arango 273
# 32 dr manuel jose 247
# 33 humberto antonio sierra 230
# 34 carlos bernal pulido 197
# 35 dra clara inés 174
# 36 dr luis ernesto 169
# 37 alejandro martinez caballero 167
# 38 dr juan carlos 166
# 39 josé fernando reyes 164
# 40 dr jorge ignacio 162
# 41 dr fabio morón 153
# 42 dr gabriel eduardo 146
# 43 juan carlos henao 141
# 44 dr jorge iván 137
# 45 antonio barrera carbonell 130
# 46 jorge ivan palacio 79
# 47 h2 style= margin 77
# 48 eduardo cifuentes muñoz 71
# 49 alexei julio estrada 65
# 50 aquiles arrieta gómez 63
# 51 hernando herrera vergara 62
# 52 dr alfredo beltran 54
# 53 mauricio gonzalez cuervo 54
# 54 jorge arango mejia 52
# 55 antonio josé lizarazo 51
# 56 dr jaime cordoba 49
# 57 maría victoria calle 47
# 58 dra clara ines 45
# 59 e dr rodrigo 41
# 60 dr simon rodriguez 35
# 61 h1 style= margin 35
# 62 dr mauricio gonzález 35
# 63 dr álvaro tafur 33
# 64 gloria stella ortiz 32
# 65 dr jaime sanin 30
# 66 luís ernesto vargas 29
# 67 ciro angarita baron 28
# 68 carlos gaviria díaz 27
# 69 h4 style= margin 26
# 70 h5 style= margin 25
# 71 e iván humberto 24
# 72 dr jorge ivan 23
# 73 alejandro martínez caballero 22
# 74 alberto rojas rios 22
# 75 carlos gaviria diaz 21
# 76 dr humberto sierra 21
# 77 rodrigo escobar gil 20
# 78 h3 style= margin 18
# 79 e josé antonio 15
# 80 dr julio cesar 15
# 81 andrés mutis vanegas 15
# 82 e richard s 14
# 83 que el médico 14
# 84 doctor jose gregorio 14
# 85 jaime córdoba triviño 13
# 86 e dra carmenza 13
# 87 razón por la 13
# 88 span style= font 13
# 89 del derecho a 12
# 90 jorge arango mejía 12
# 91 esencial de la 12
# 92 e dra martha 11
# 93 doctor jorge arango 10
# 94 ordenó que se 10
# 95 e dra cristina 10
# 96 dra maría victoria 10
# 97 dr jairo charry 9
# 98 esencial del derecho 9
# 99 cristina pardo schlesinger 9
# 100 doctor ciro angarita 9
# 101 marco gerardo monroy 8
# 102 alvaro tafur galvis 7
# 103 ciro angarita barón 7
# 104 diana fajardo rivera 7
# 105 martha victoria sáchica 7
# 106 dr luís ernesto 6
# 107 dr ciro angarita 6
# 108 fabio morón díaz 6
# 109 jaime araújo rentería 6
# 110 josé antonio cepeda 6
# 111 e dr jairo 6
# 112 dr mauricio gonzalez 5
# 113 dra cristina pardo 5
# 114 vladimiro naranjo mesa 5
# 115 e adriana maria 5
# 116 magistrado josé gregorio 5
# 117 h6 style= margin 5
# 118 h3 h3 style= 5
# 119 fabio moron diaz 5
# 120 maria victoria calle 5
# 121 magistrado jose gregorio 5
# 122 manuel josé cepeda 5
# 123 de la ayuda 5
# 124 dr rodrigo uprimny 5
# 125 del sistema de 5
# 126 de la seguridad 5
# 127 simon rodriguez rodriguez 4
# 128 de la sentencia 4
# 129 que los médicos 4
# 130 dr jaime araùjo 4
# 131 jaime sanin greiffenstein 4
# 132 de la reparación 4
# 133 esenciales de la 4
# 134 del derecho de 4
# 135 del derecho fundamental 4
# 136 propios del bienestar 3
# 137 educativos que pueden 3
# 138 e myriam avila 3
# 139 de la prórroga 3
# 140 de la política 3
# 141 del debido proceso 3
# 142 martha victoria sachica 3
# 143 el derecho a 3
# 144 eduardo montealegre lynett 3
# 145 e adriana maría 3
# 146 alfredo beltrán sierra 3
# 147 dr nilson pinillla 3
# 148 jaime araujo renteria 3
# 149 del sistema educativo 3
# 150 del proyecto de 3
# 151 adriana maría guillén 3
# 152 del principio de 3
# 153 de acceso disponibilidad 3
# 154 derecho a la 3
# 155 prestacionales reconocidos y 3
# 156 etapas y fases 3
# 157 esencial del debido 3
# 158 myriam ávila roldán 3
# 159 fundamental que integra 3
# 160 e dra clara 3
# 161 fundamentales del juicio 2
# 162 clara inés vargas 2
# 163 y ii exponer 2
# 164 de este derecho 2
# 165 class=msonormal style= margin 2
# 166 del derecho al 2
# 167 e h1 style= 2
# 168 y iii programación 2
# 169 de promoción prevención 2
# 170 esencial de este 2
# 171 básicos de información 2
# 172 según jurisprudencia de 2
# 173 0cm margin left 2
# 174 href= ftn1 name= 2
# 175 span lang=es co 2
# 176 con el fin 2
# 177 presupuestos para que 2
# 178 así como los 2
# 179 el estado debe 2
# 180 de un conjunto 2
# 181 e myriam ávila 2
# 182 actúe como compartimento 2
# 183 más importantes de 2
# 184 a la educacion 2
# 185 de los programas 2
# 186 de la identidad 2
# 187 podrá decretar de 2
# 188 mediante auto de 2
# 189 y en esa 2
# 190 e hernán correa 2
# 191 luis ernesto varga 2
# 192 de la inversión 2
# 193 del territorio colombiano 2
# 194 no puede comprometer 2
# 195 luís guillermo guerrero 2
# 196 alberto rojas rêos 2
# 197 de habitabilidad ante 2
# 198 que permitan garantizar 2
# 199 esenciales que delimitan 2
# 200 e dra catalina 2
# 201 e h2 style= 2
# 202 jose fernando reyes 2
# 203 de la libertad 2
# 204 mediante auto del 2
# 205 de accesibilidad reiteración 2
# 206 iván humberto escrucería 2
# 207 inseparables liquidacion de 2
# 208 de alojamiento temporal 2
# 209 adriana maria guillen 2
# 210 de la base 2
# 211 que refuerza el 2
# 212 esenciales y hace 2
# 213 size 14 0pt 2
# 214 dra martha victoria 2
# 215 deberá consignar la 2
# 216 e andrés mutis 2
# 217 básicos del derecho 2
# 218 i el sistema 2
# 219 inseparables base reguladora 2
# 220 que eleven el 2
# 221 dres jorge arango 2
# 222 dra mirén de 2
# 223 h1dr jaime araujo 2
# 224 jorge enrique ibáñez 2
# 225 esenciales del derecho 2
# 226 adriana m guillén 2
# 227 altere el entorno 2
# 228 puede decretar las 1
# 229 personal inevitable pues 1
# 230 de esta iniciativa 1
# 231 establecido para resolver 1
# 232 de reincorporacion politica 1
# 233 económico informalidad minera 1
# 234 religioso precedente fijado 1
# 235 tributo competencia para 1
# 236 físicos urbanos y 1
# 237 me permito aclarar 1
# 238 logístico documental y 1
# 239 del impuesto de 1
# 240 personas con las 1
# 241 myriam ávila roldan 1
# 242 prestacional no lo 1
# 243 gin bottom 0001pt 1
# 244 10 i solicitó 1
# 245 axial en el 1
# 246 económico o monetario 1
# 247 de la sección 1
# 248 de la agenda 1
# 249 w roman serif 1
# 250 decidendi obiter dictum 1
# 251 de los derechos 1
# 252 1 el relativo 1
# 253 del 7 de 1
# 254 de la tutela 1
# 255 doctor josé gregorio 1
# 256 conforme se observa 1
# 257 alejandro martinez caballlero 1
# 258 básicos por asambleas 1
# 259 particular y previamente 1
# 260 anatomicos inhibición por 1
# 261 una vez cumplidos 1
# 262 in bottom 0cm 1
# 263 de habitabilidad al 1
# 264 rafael e ostau 1
# 265 de las comisiones 1
# 266 dr hernado herrera 1
# 267 jairo e duque 1
# 268 i reducción en 1
# 269 de alimentación salud 1
# 270 dra clara elena 1
# 271 dr jaime vidal 1
# 272 de alimentación alojamiento 1
# 273 e n bottom 1
# 274 esencial 1 preparación 1
# 275 raph dr vladimiro 1
# 276 y productos usualmente 1
# 277 josé antonio lizarazo 1
# 278 no iba poder 1
# 279 dr manuel span 1
# 280 h1 h1 style= 1
# 281 quien hoy conduce 1
# 282 esenciales esta exigencia 1
# 283 y inter ideograph 1
# 284 h3dr jaime araujo 1
# 285 ttom 0cm margin 1
# 286 puede lograrse a 1
# 287 constitucionales y legales 1
# 288 tyle= font size 1
# 289 el registro de 1
# 290 del paquete de 1
# 291 de defensa tcnica 1
# 292 ley de apropiaciones 1
# 293 teleológico la participación 1
# 294 h3 style= line 1
# 295 caso en que 1
# 296 determinante de la 1
# 297 que la jurisprudencia 1
# 298 de su patrimonio 1
# 299 consideren relevantes no 1
# 300 y quienes hayan 1
# 301 h2 h2 style= 1
# 302 de accesibilidad universal 1
# 303 del referido proceso 1
# 304 como quiera que 1
# 305 subjetivos que lo 1
# 306 de la sanción 1
# 307 la idea de 1
# 308 de justicia distributiva 1
# 309 meramente estético y 1
# 310 esenciales del recomendado 1
# 311 inmobiliarios impuesto sobre 1
# 312 del iva de 1
# 313 proyecto de ley 1
# 314 el 14 de 1
# 315 de integralidad accesibilidad 1
# 316 fundamentales ya que 1
# 317 margin left 7 1
# 318 surgen deberes específicos 1
# 319 gn justify text 1
# 320 class=msonormal style= text 1
# 321 carlos gavira diaz 1
# 322 exencion tributaria condición 1
# 323 el oficio bz 1
# 324 para evitar dilaciones 1
# 325 y iii exponer 1
# 326 jorge ignacio preteltchaljub 1
# 327 esenciales del desarrollo 1
# 328 esencial del ordenamiento 1
# 329 de la ruta 1
# 330 étnico en un 1
# 331 dra catalina botero 1
# 332 quien pudo dar 1
# 333 que integre el 1
# 334 discriminatorio igualdad de 1
# 335 que integran el 1
# 336 idóneo para que 1
# 337 normativos que inciden 1
# 338 de diseño universal 1
# 339 h6dr alvaro tafur 1
# 340 económico a través 1
# 341 y prestaciones en 1
# 342 drs josé gregorio 1
# 343 el inciso primero 1
# 344 territoriales creación legalcongreso 1
# 345 del concepto de 1
# 346 v la acumulación 1
# 347 primigenio indispensable que 1
# 348 consideró necesario disponer 1
# 349 y etapas referencia 1
# 350 anatómicos importados y 1
# 351 no consignaron dentro 1
# 352 dr nilosn pinilla 1
# 353 estructurales del derecho 1
# 354 ight 16 75pt 1
# 355 ht 16 75pt 1
# 356 mal style= margin 1
# 357 rechazó la demanda 1
# 358 así frente a 1
# 359 dra maria victoria 1
# 360 p dr jaime 1
# 361 de los acuerdos 1
# 362 doctor fabio morón 1
# 363 por secretaría general 1
# 364 sigue convencido de 1
# 365 tramita asuntos que 1
# 366 atención en salud 1
# 367 o los servidores 1
# 368 rgin bottom 0001pt 1
# 369 75pt margin bottom 1
# 370 h6dr jaime córdoba 1
# 371 preferente y principal 1
# 372 que tengan la 1
# 373 anatomicos a extranjeros 1
# 374 se refieren a 1
# 375 se encuentran comprendidos 1
# 376 dr antoniobarrera carbonell 1
# 377 económico en lo 1
# 378 esenciales del pot 1
# 379 discriminatorio por ello 1
# 380 que considere necesario 1
# 381 para el goce 1
# 382 del deber de 1
# 383 adriana guillén arango 1
# 384 que hacen parte 1
# 385 explican en la 1
# 386 legalidad de los 1
# 387 b del pacto 1
# 388 ter ideograph dr 1
# 389 ormal style= margin 1
# 390 que activa la 1
# 391 de la competencia 1
# 392 de la providencia 1
# 393 dr mal style= 1
# 394 axiológicos del ordenamiento 1
# 395 básicodebido proceso en 1
# 396 marítimos el subsuelo 1
# 397 de los dineros 1
# 398 esencial derecho penal 1
# 399 estricto de la 1
# 400 ciro angarita bar0n 1
# 401 más importantes igualmente 1
# 402 tal hecho no 1
# 403 decidió admitir la 1
# 404 b cuestiones previas 1
# 405 de manera clara 1
# 406 médico previsto para 1
# 407 dr rodrlgo escobar 1
# 408 en procesos de 1
# 409 no puede justificarse 1
# 410 del núcleo familiar 1
# 411 xt align justify 1
# 412 margin right 11 1
# 413 del beneficio tributario 1
# 414 prioritario de los 1
# 415 separados a procedimientos 1
# 416 algunas pruebas para 1
# 417 al doctor dídier 1
# 418 esenciales del sistema 1
# 419 dr omar enrique 1
# 420 en interacción recíproca 1
# 421 en alusión al 1
# 422 del núcleo esencial 1
# 423 jurídico del sistema 1
# 424 subsidio familiar características 1
# 425 de la obligación 1
# 426 disponibilidad accesibilidad aceptabilidad 1
# 427 de la conducta 1
# 428 del vínculo tributario 1
# 429 font size 14 1
# 430 naval de apostadero 1
# 431 i financiación y 1
# 432 más importantes y 1
# 433 directamente entrelazados que 1
# 434 h4 dra clara 1
# 435 del contrato de 1
# 436 dra humberto antonio 1
# 437 pt margin bottom 1
# 438 de carácter fundamental 1
# 439 fundamental de lucha 1
# 440 comportamiento contrario a 1
# 441 solicitó declarar improcedente 1
# 442 las cotizaciones de 1
# 443 no se agota 1
# 444 inseparables que condicionan 1
# 445 estudiaron y finalmente 1
# 446 de una manera 1
# 447 obligatorio pretensión se 1
# 448 elementales del núcleo 1
# 449 constituyen o no 1
# 450 pro homine en 1
# 451 esencial e insustituible 1
# 452 respecto de los 1
# 453 cancelación la autoridad 1
# 454 alojamiento transitorio y 1
# 455 ign justify text 1
# 456 libertad de concurrencia 1
# 457 importante del convenio 1
# 458 de ayuda requeridos 1
# 459 territorial hipótesis de 1
# 460 transversal que abarca 1
# 461 de continuidad así 1
# 462 prestacional y requiere 1
# 463 delegacion de funciones 1
# 464 que agota el 1
# 465 iv de manera 1
# 466 en la legislación 1
# 467 el oficio 2017 1
# 468 para determinar el 1
# 469 principal de la 1
# 470 y presentacion de 1
# 471 de modo que 1
# 472 tecnológico e incluso 1
# 473 del tributo o 1
# 474 de la violencia 1
# 475 el artículo 29 1
# 476 t 7 0cm 1
# 477 esencial el interés 1
# 478 integrante del interés 1
# 479 jairo jiménez aristizabal 1
# 480 de un tipo 1
# 481 sentencia t 113303 1
# 482 incumplidos así tales 1
# 483 esenciales carecen de 1
# 484 dr al varo 1
# 485 93 el registro 1
# 486 hernan olano garcia 1
# 487 álvaro tafur galvis 1
# 488 de violencia y 1
# 489 afectivo que en 1
# 490 en el mundo 1
# 491 de la supervisión 1
# 492 la carta adopta 1
# 493 rup finalidad de 1
# 494 dr jos gregorio 1
# 495 institucional y procesal 1
# 496 al proveer sobre 1
# 497 básico de la 1
# 498 por la misma 1
# 499 químicos o propiedades 1
# 500 del mismo y 1
# 501 constitutivo de la 1
# 502 cuando no exista 1
# 503 manuel jose cepeda 1
# 504 de la ratio 1
# 505 podrá adoptar una 1
# 506 directamente entrelazados compuesto 1
# 507 de la higiene 1
# 508 0pt dr carlos 1
# 509 más adecuado oportuno 1
# 510 básicosprincipio de autonomia 1
# 511 de la diversidad 1
# 512 naturales el derecho 1
# 513 es condición indispensable 1
# 514 ext justify inter 1
# 515 participativo papel en 1
# 516 anatómicos a extranjeros 1
# 517 son artículos de 1
# 518 sean parcialmente reformulados 1
# 519 e luis javier 1
# 520 en el proceso 1
# 521 dr luis erensto 1
# 522 para publicación de 1
# 523 las responsabilidades y 1
# 524 integrales del derecho 1
# 525 dr fidalgo javier 1
# 526 de participación política 1
# 527 que obliga de 1
# 528 ordenó oficiar al 1
# 529 dr jaimen sanin 1
# 530 de asistencia mínima 1
# 531 del tributo tales 1
# 532 dr span style= 1
# 533 que se recibieron 1
# 534 de integración de 1
# 535 fácticos es claro 1
# 536 social que obliga 1
# 537 doctor carlos gustavo 1
# 538 de naturaleza variable 1
# 539 la protección por 1
# 540 e inclusión de 1
# 541 son los siguientes 1
# 542 del sistema nacional 1
# 543 de cada delito 1
# 544 el derecho fundamental 1
# 545 también resulta jurídicamente 1
# 546 que su informe 1
# 547 de archivística constituyera 1
# 548 la constitución política 1
# 549 siendo las cámaras 1
# 550 dr alejandromartinez caballero 1
# 551 de restitución exige 1
# 552 memoriales suscritos por 1
# 553 del sivjrnr actúan 1
# 554 magistrado onormal align=center 1
# 555 antonio barrera carbonelll 1
# 556 esencial derecho de 1
# 557 graph dr simon 1
# 558 inseparables pension de 1
# 559 de la indemnización 1
# 560 fundamentales a pesar 1
# 561 disciplinario la norma 1
# 562 argumentando que él 1
# 563 e ministerio de 1
# 564 esenciales del debido 1
# 565 dr luis ernsesto 1
# 566 realizó consulta ante 1
# 567 en materia salarial 1
# 568 de transferencia de 1
# 569 por tal razón 1
# 570 es precisamente el 1
# 571 del caso considera 1
# 572 left 7 0cm 1
# 573 del régimen prestacional 1
# 574 sea cumplido a 1
# 575 0001pt text align 1
# 576 stify text justify 1
# 577 drs vladimiro naranjo 1
# 578 ordenó fijar en 1
# 579 donald josé dix 1
# 580 solicitando negar la 1
# 581 en contratacion estatal 1
# 582 gloria stella ortíz 1
# 583 h2 style= text 1
# 584 informativo y pedagógico 1
# 585 básico derecho al 1
# 586 ify inter ideograph 1
# 587 irregularidad en tramite 1
# 588 se enmarcan dentro 1
# 589 inicial o de 1
# 590 dentro de los 1
# 591 podrá en cualquier 1
# 592 horizontal es eminentemente 1
# 593 importante de la 1
# 594 4 0pt color 1
# 595 propio de la 1
# 596 que busca su 1
# 597 no están exentos 1
# 598 dr eduardo cifuentez 1
# 599 afectivos y emocionales 1
# 600 olvidó indicar explícitamente 1
# 601 de accesibilidad a 1
# 602 margin right 16 1
# 603 de asequibilidad accesibilidad 1
# 604 religioso al afectar 1
# 605 objetivo del estado 1
# 606 de la calidad 1
# 607 de dicho derecho 1
# 608 josé gregorio hernández 1
# 609 de asequibilidad derecho 1
# 610 y su interrelación 1
# 611 que caracterizan nuestra 1
# 612 para cálculo de 1
# 613 del espacio publico 1
# 614 anatómicos dignos de 1
# 615 el director adjuntó 1
# 616 básicos de la 1
# 617 de organismos genéticamente 1
# 618 de haberse hecho 1
# 619 de gasto del 1
# 620 básico para la 1
# 621 mínimos protegidos por 1
# 622 en el fallo 1
# 623 central del derecho 1
# 624 base y porcentaje 1
# 625 de segundo debate 1
# 626 inseparables el monto 1
# 627 deograph dr alvaro 1
# 628 incurrió en la 1
# 629 de la justicia 1
# 630 ante la necesidad 1
# 631 definitorios esenciales en 1
# 632 de jorge arango 1
# 633 left 198 9pt 1
# 634 como derecho a 1
# 635 de sensibilidad social 1
# 636 que la sala 1
# 637 sancionatorio buscan aminorar 1
# 638 de la habitabilidad 1
# 639 del fallo atacado 1
# 640 ahora bien la 1
# 641 de rehabilitación del 1
# 642 fáctico común de 1
# 643 iv el deber 1
# 644 de atención que 1
# 645 preventivo derecho a 1
# 646 de la parte 1
# 647 a los comisionados 1
# 648 desplazados reglamentación de 1
# 649 subjetivos adicionalesacto punible 1
# 650 11 7 2 1
# 651 de igualdad problemas 1
# 652 dr jaime sanín 1
# 653 han sido clasificados 1
# 654 étnicamente diferenciado de 1
# 655 lang=es co style= 1
# 656 f no sólo 1
# 657 para que el 1
# 658 dr jacobo pérez 1
# 659 anatómicos derecho a 1
# 660 pensional como en 1
# 661 inadmitió la demanda 1
# 662 judicial del sistema 1
# 663 la objetividad en 1
# 664 haya sido hecho 1
# 665 exentos ref d 1
# 666 de un servicio 1
# 667 estos son i 1
# 668 198 9pt margin 1
# 669 sexo del registro 1
# 670 del auto acusado 1
# 671 de suspensión se 1
# 672 admite la intervención 1
# 673 un juicioso análisis 1
# 674 de la medida 1
# 675 del snaipd y 1
# 676 observaciones ciudadanas a 1
# 677 necesario para lograr 1
# 678 plebiscitario al paso 1
# 679 y no tiene 1
# 680 estructurales en su 1
# 681 eduardo cifuentes agosto 1
# 682 específico del derecho 1
# 683 que garantizan la 1
# 684 las pruebas enviadas 1
# 685 solicitó el aporte 1
# 686 y v un 1
# 687 jose gregorio hernandez 1
# 688 de la ley 1
# 689 en contratacion administrativa 1
# 690 recurre a posturas 1
# 691 adriana maria guillén 1
# 692 esenciales se encuentran 1
# 693 e gloria stella 1
# 694 ii las gacetas 1
# 695 social demuestra una 1
# 696 y elementos accion 1
# 697 al resolver sobre 1
# 698 usos volumen peso 1
# 699 de los proyectos 1
# 700 lu bogotá dc 1
# 701 jaime araujo rentería 1
# 702 esencial y por 1
# 703 sancionatorio del código 1
# 704 rechazando la demanda 1
# 705 leve carga que 1
# 706 principales autonomia universitaria 1
# 707 como una estrategia 1
# 708 doctor alfredo beltrán 1
# 709 central en el 1
# 710 resocializador justicia transicional 1
# 711 oneroso ahora dada 1
# 712 inter ideograph dr 1
# 713 fundamental del ordenamiento 1
# 714 sobre el caso 1
# 715 s tiene n 1
# 716 del derecho disciplinario 1
# 717 h5 h5 style= 1
# 718 de la individualidad 1
# 719 centrales la separación 1
# 720 h4 align=left style= 1
# 721 en este caso 1
# 722 el dr alfredo 1
# 723 imprescindibles para permitir 1
# 724 que establece la 1
# 725 dr hernando gómez 1
# 726 de reparación económica 1
# 727 vinculó al iss 1
# 728 ass=msonormal style= margin 1
# 729 para que adoptara 1
# 730 deben respetar los 1
# 731 sonormal style= margin 1
# 732 presupuesto de gastos 1
# 733 lúdicos y el 1
# 734 solicitó tanto a 1
# 735 del auto que 1
# 736 de las decisiones 1
# 737 equidad tributaria definición 1
# 738 invariables cuales son 1
# 739 y una justificación 1
# 740 del proyecto artículo 1
# 741 del pacto por 1
# 742 de derecho a 1
# 743 prestacionales necesarios para 1
# 744 no existan las 1
# 745 de la atención 1
# 746 anatomicos post mortem 1
# 747 justify inter ideograph 1
# 748 e rodrigo uprimny 1
# 749 básicos reparacion integral 1
# 750 incidente de reparacion 1
# 751 otorgando a las 1
# 752 del derecho se 1
# 753 fecha recibido por 1
# 754 control participativo desarrollo 1
# 755 interdisciplinario existencia de 1
# 756 h4dr álvaro tafur 1
# 757 fáctico constituido por 1
# 758 esencial del proyecto 1
# 759 orgánicos del estado 1
# 760 de la sala 1
# 761 right 2 55pt 1
# 762 consideran que así 1
# 763 dejando en cabeza 1
# 764 en efecto el 1
# 765 en proceso de 1
# 766 organico o institucional 1
# 767 ii consideraciones de 1
# 768 an lang=es co 1
# 769 no obstante que 1
# 770 básicos del núcleo 1
# 771 adversarial del sistema 1
# 772 de reparacion integral 1
# 773 de dicho texto 1
# 774 solidario que depende 1
# 775 principio de generalidad 1
# 776 en los procesos 1
# 777 de ayuda referencia 1
# 778 en trámite de 1
# 779 es co style= 1
# 780 procedió a rechazar 1
# 781 la carga de 1
# 782 estructurales del problema 1
# 783 doctores jose gregorio 1
# 784 el resarcimiento por 1
# 785 =msonormal style= margin 1
# 786 la jurisprudencia constitucional 1
# 787 h5dr rodrigo escobar 1
# 788 de la protección 1
# 789 cruciales de su 1
# 790 fundamentales es la 1
# 791 denominado gasto público 1
# 792 dr vladimirio naranjo 1
# 793 corpóreo indiscutible por 1
# 794 coercitivo y en 1
# 795 esenciales cual es 1
# 796 prestacional del derecho 1
# 797 dr guillermo gonzález 1
# 798 e h5 style= 1
# 799 especial consistente en 1
# 800 de la fiscalía 1
# 801 pues no hay 1
# 802 ofició a coomeva 1
# 803 del cuadro clínico 1
# 804 constitutivos y complementarios 1
# 805 iii dr jaime 1
# 806 julio cesar ortiz 1
# 807 como fundamento para 1
# 808 0cm margin right 1
# 809 top 0cm margin 1
# 810 luis carlos sáchica 1
# 811 h3 h2 style= 1
# 812 inflacionario o de 1
# 813 que no compromete 1
# 814 8 primero ordenar 1
# 815 el principio de 1
# 816 indefectible de la 1
# 817 dr fabio morn 1
# 818 adopte las medidas 1
# 819 económico del derecho 1
# 820 de vivienda del 1
# 821 de que se 1
# 822 que pueden incorporarse 1
# 823 religioso católico con 1
# 824 existe una amplia 1

# %% [markdown]
# ## **[EN CONSTRUCCIÓN] Análisis de frecuencia de palabras**

# %%
df["palabras"] = [len(doc.split()) for doc in df.pp.values]

# %%
fig, ax = plt.subplots(1,1)
# fig.set_figheight(15)
# fig.set_figwidth(15)
# # ax.set_size_inches(10,15)
ax.set_xlim(10000)
ax.rev
ax.hist(df.palabras.values, bins=10000)

# data['pm2.5'].hist(bins=1000,grid=False)
# ax.set_xlabel("Palabras", fontsize=15)
# ax.set_ylabel("Documentos",fontsize=15)
plt.show()

# %%
np.argmax(df.palabras.values)
# Out:
# 33328

# %%
print(df.iloc[np.argmax(df.palabras.values)].LINK)
# Out:
# https://www.corteconstitucional.gov.co/Relatoria/1996/C-037-96.htm

# %%
from bs4 import BeautifulSoup

# %%
main_soup = BeautifulSoup(df.iloc[np.argmax(df.palabras.values)].DOCUMENT, 'lxml')

# %%
main_soup.text
# Out:
# 'LEY ESTATUTARIA JUSTICIA\n\n\n'

# %%
with open("sentencia_sucia.txt", "w") as f:
    f.write(df.iloc[np.argmax(df.palabras.values)].DOCUMENT)

# %%
X = ['mi mamá me mima', 'mi mamá me ama', 'amo a mi mamá']

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vec = CountVectorizer(ngram_range=(1,3))
vec.fit(X)
# Out:
# CountVectorizer(ngram_range=(1, 3))

# %%
vec.vocabulary_
# Out:
# {'mi': 11,
#  'mamá': 4,
#  'me': 8,
#  'mima': 14,
#  'mi mamá': 12,
#  'mamá me': 5,
#  'me mima': 10,
#  'mi mamá me': 13,
#  'mamá me mima': 7,
#  'ama': 0,
#  'me ama': 9,
#  'mamá me ama': 6,
#  'amo': 1,
#  'amo mi': 2,
#  'amo mi mamá': 3}
